# %% [markdown]
# ### What is Pyspark?
# Spark is the name of the engine to implement cluster computing in your multi-core multi-chip computing system, while PySpark is the Python's library to use Spark.
#
# Spark is written in Scala and it provides APIs to work with Scala, JAVA, Python, and R.
#
# PySpark is the Python API written in Python to support Spark.
#
# I will show case this work book with  a 30GB unzipped data with a i7 computer with 12 cores and 16GB as the compute platform.

# %%
# !python --version

## Some inconsistencies in running spark in 3.7?
# Out:
# Python 3.7.4

# %% [markdown]
# Now let us test the if our installation was successful using the code as below

# %% [markdown]
# #### Find spark
# PySpark isn't on sys.path by default, but that doesn't mean it can't be used as a regular library.
# You can address this by either symlinking pyspark into your site-packages,
# or adding pyspark to sys.path at runtime. findspark does the latter.

# %% [markdown]
# Run the following only after you successfully run the above code without error

# %%
#   !pip install findspark   # already installed in usss
import findspark

findspark.init()    # adds the path (location) to the execution step automatically

# %% [markdown]
# PySpark Public classes:
#
# #### SparkContext:
# Entry point for Spark functionality.
#
# #### RDD:
# Resilient Distributed Dataset (RDD), the basic abstraction of creating and managing data sets in Spark.
#
# Broadcast:
# Broadcast variable that gets reused across tasks; a task
#
# A task is a command sent from the driver to an executor by serializing your Function object. The executor deserializes the command (this is possible because it has loaded your jar), and executes it on a partition. (stackoverflow.com)
#
# Accumulator:
# An “add-only” shared variable that tasks can only add values to. It is used to implement a counter or cumulative sum and works for parallel implementation
#
# #### SparkConf:
# Spark context instantiates Spark engine which application will run in which mode(local/cluster mode?
#
# SparkFiles:
# Access files shipped with jobs.
#
# StorageLevel:
# Finer-grained cache persistence levels.
#
# TaskContext:
# Information about the current running task, available on the workers and experimental.
#
# RDDBarrier:
# Wraps an RDD under a barrier stage for barrier execution.
#
# BarrierTaskContext:
# A TaskContext that provides extra info and tooling for barrier execution.
#
# BarrierTaskInfo:
# Information about a barrier task.

# %% [markdown]
# ### Important classes of Spark SQL and DataFrames:
#
# pyspark.sql.SQLContext Main entry point for DataFrame and SQL functionality.
#
# pyspark.sql.DataFrame A distributed collection of data grouped into named columns.
#
# pyspark.sql.Column A column expression in a DataFrame.
#     Ex: df.select('zip_code').show() is head() output as in python
#
# pyspark.sql.Row A row of data in a DataFrame.
#     Ex: df.sql.Row
#
# pyspark.sql.HiveContext Main entry point for accessing data stored in Apache Hive.
#
# pyspark.sql.GroupedData Aggregation methods, returned by DataFrame.groupBy().
#
# pyspark.sql.DataFrameNaFunctions Methods for handling missing data (null values).
#
# pyspark.sql.DataFrameStatFunctions Methods for statistics functionality.
#
# pyspark.sql.functions List of built-in functions available for DataFrame.
#
# pyspark.sql.types List of data types available.
#
# pyspark.sql.Window For working with window functions.
#
# Read: https://www.dataneb.com/spark-scala-tutorial (why spark and how scala is foundational though java, scala, python, and R are interchangeably used in Jeppelin notebook.
#
# read: https://www.dataneb.com/post/sparkcontext-scala (what is meant by spark-shell?)

# %%
from pyspark.sql import SparkSession 

# access the builder to get into existing SparkSession creating a simpler name
spark = SparkSession.builder.getOrCreate()

# we will get more relevant methods as we see useful while building the data science steps below

spark.stop()

# %%
# pyspark is a superset of python with essential classes from python foundation and hence 

# pythonic programmatic statements are usable directly; technically a senior python solution 
# developer can start the day with pyspark if his/her work always involves pyspark as central to work; 

# This is true especially for a sr. data scientist

import random, pyspark
num_samples = 10000

def inside(p):     
  x, y = random.random(), random.random()
  return x*x + y*y < 1

#sc = pyspark.SparkContext() # for first time 
sc = pyspark.SparkContext.getOrCreate()



count = sc.parallelize(range(0, num_samples)).filter(inside).count()

pi = 4 * count / num_samples
print(pi)

sc.stop()
# Out:
# 3.114

# %% [markdown]
# You can apply a transformation to the data with a lambda function. In the example below, you return the square of nums. It is a map transformation
#
# Python map object is an iterator, so we can iterate over its elements. We can also convert map object to sequence objects such as list, tuple etc.
#
# Because spark lives 'lazy' for all operations, we need to 'collect' the outputs from any operation

# %%
sc=pyspark.SparkContext.getOrCreate()

nums=sc.parallelize([1,2,-3,4,10])
nums.take(1)

type(nums)

# Resilient Distributed Data structure is created unless you ask for dataset or dataframe
# Out:
# pyspark.rdd.RDD

# %%
squared = nums.map(lambda x: x*x).collect()  
# Because spark lives 'lazy' for all operations, we need to 'collect' the outputs from any operation
for num in squared:
    print('%i ' % (num))
# Out:
# 1
# 4
# 9
# 16
# 100

# %% [markdown]
# # SQLContext
# A more convenient way is to use the DataFrame. SparkContext is already set, you can use it to create the dataFrame. You also need to declare the SQLContext
#
# SQLContext allows connecting the engine with different data sources. It is used to initiate the functionalities of Spark SQL.

# %%
from pyspark.sql import Row
from pyspark.sql import SQLContext

sqlContext = SQLContext(sc)

# %% [markdown]
# # Let's create a list of tuple. Each tuple will contain the name of the people and their age. Four steps are required:
#
# Step 1) Create the list of tuple with the information

# %%
list_p = [('John',19),('Smith',29),('Adam',35),('Henry',50)]

# %% [markdown]
# Step 2) Build a RDD

# %%
rdd = sc.parallelize(list_p)

# %% [markdown]
# Step 3) Convert the tuples

# %%
ppl = rdd.map(lambda x: Row(name=x[0], age=int(x[1]))).collect()

print(ppl)
# Out:
# [Row(age=19, name='John'), Row(age=29, name='Smith'), Row(age=35, name='Adam'), Row(age=50, name='Henry')]

# %% [markdown]
# Step 4) Create a DataFrame context

# %%
sqlContext.createDataFrame(ppl)
list_p = [('John',19),('Smith',29),('Adam',35),('Henry',50)]
rdd = sc.parallelize(list_p)
ppl = rdd.map(lambda x: Row(name=x[0], age=int(x[1])))
DF_ppl = sqlContext.createDataFrame(ppl)

# %% [markdown]
# If you want to access the type of each feature, you can use printSchema()

# %%
DF_ppl.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %% [markdown]
# you need to initialize the SQLContext is not already in initiated yet.

# %%
#from pyspark.sql import SQLContext

path = "C:\\users\\usss\\Downloads\\adult-data\\adult-data.csv"

from pyspark import SparkFiles
sc.addFile(path)
sqlContext = SQLContext(sc)

# %% [markdown]
# you can read the cvs file with sqlContext.read.csv. You use inferSchema set to True to tell Spark to guess automatically the type of data. By default, it is turn to False.

# %%
df = sqlContext.read.csv(SparkFiles.get("adult-data.csv"), header=True, inferSchema= True)

# %% [markdown]
#  have a look at the data type

# %%
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- workclass: string (nullable = true)
#  |-- fnlwgt: integer (nullable = true)
#  |-- education: string (nullable = true)
#  |-- education_num: integer (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- occupation: string (nullable = true)
#  |-- relationship: string (nullable = true)
#  |-- race: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- capital-gain: integer (nullable = true)
#  |-- capital-loss: integer (nullable = true)
#  |-- wrk_hrs_per_week: integer (nullable = true)
#  |-- native_country: string (nullable = true)
#  |-- income: string (nullable = true)

# %%
#You can see the data with show.

df.show(5, truncate = False)
# Out:
# +---+-----------------+------+----------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+----------------+--------------+------+
# |age|workclass        |fnlwgt|education |education_num|marital_status     |occupation        |relationship  |race  |sex    |capital-gain|capital-loss|wrk_hrs_per_week|native_country|income|
# +---+-----------------+------+----------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+----------------+--------------+------+
# |39 | State-gov       |77516 | Bachelors|13           | Never-married     | Adm-clerical     | Not-in-family| White| Male  |2174        |0           |40              | United-States| <=50K|
# |50 | Self-emp-not-inc|83311 | Bachelors|13           | Married-civ-spouse| Exec-managerial  | Husband      | White| Male  |0           |0           |13              | United-States| <=50K|
# |38 | Private         |215646| HS-grad  |9            | Divorced          | Handlers-cleaners| Not-in-family| White| Male  |0           |0           |40              | United-States| <=50K|
# |53 | Private         |234721| 11th     |7            | Married-civ-spouse| Handlers-cleaners| Husband      | Black| Male  |0           |0           |40              | United-States| <=50K|
# |28 | Private         |338409| Bachelors|13           | Married-civ-spouse| Prof-specialty   | Wife         | Black| Female|0           |0           |40              | Cuba         | <=50K|
# +---+-----------------+------+----------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+----------------+--------------+------+
# only showing top 5 rows

# %% [markdown]
# If you didn't set inferSchema to True, here is what is happening to the type. There are all in string.

# %%
df_string = sqlContext.read.csv(SparkFiles.get("adult-data.csv"), header=True, inferSchema=  False)
df_string.printSchema()
# Out:
# root
#  |-- age: string (nullable = true)
#  |-- workclass: string (nullable = true)
#  |-- fnlwgt: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- education_num: string (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- occupation: string (nullable = true)
#  |-- relationship: string (nullable = true)
#  |-- race: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- capital-gain: string (nullable = true)
#  |-- capital-loss: string (nullable = true)
#  |-- wrk_hrs_per_week: string (nullable = true)
#  |-- native_country: string (nullable = true)
#  |-- income: string (nullable = true)

# %% [markdown]
# To convert the continuous variable in the right format, you can use recast the columns. You can use withColumn to tell Spark which column to operate the transformation.

# %%
# Import all from `sql.types`
from pyspark.sql.types import *

# Write a custom function to convert the data type of DataFrame columns
def convertColumn(df, names, newType):
    for name in names: 
        df = df.withColumn(name, df[name].cast(newType))
    return df

# %%
# List of continuous features
CONTI_FEATURES  = ['age', 'fnlwgt','capital-gain', 'education_num', 'capital-loss', 'wrk_hrs_per_week']

# %%
# Convert the type
df_string = convertColumn(df_string, CONTI_FEATURES, FloatType())

# %%
from pyspark.ml.feature import StringIndexer
#stringIndexer = StringIndexer(inputCol="label", outputCol="newlabel")
#model = stringIndexer.fit(df)
#df = model.transform(df)
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- workclass: string (nullable = true)
#  |-- fnlwgt: integer (nullable = true)
#  |-- education: string (nullable = true)
#  |-- education_num: integer (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- occupation: string (nullable = true)
#  |-- relationship: string (nullable = true)
#  |-- race: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- capital-gain: integer (nullable = true)
#  |-- capital-loss: integer (nullable = true)
#  |-- wrk_hrs_per_week: integer (nullable = true)
#  |-- native_country: string (nullable = true)
#  |-- income: string (nullable = true)

# %% [markdown]
# # Select columns
# You can select and show the rows with select and the names of the features. Below, age and fnlwgt are selected.

# %%
df.select('age','fnlwgt').show(5)
# Out:
# +---+------+
# |age|fnlwgt|
# +---+------+
# | 39| 77516|
# | 50| 83311|
# | 38|215646|
# | 53|234721|
# | 28|338409|
# +---+------+
# only showing top 5 rows

# %% [markdown]
# # Count by group
# If you want to count the number of occurence by group, you can chain:
#
# groupBy()
# count()
# together. In the example below, you count the number of rows by the education level.

# %%
df.groupBy("education").count().sort("count",ascending=True).show()
# Out:
# +-------------+-----+
# |    education|count|
# +-------------+-----+
# |    Preschool|   51|
# |      1st-4th|  168|
# |      5th-6th|  333|
# |    Doctorate|  413|
# |         12th|  433|
# |          9th|  514|
# |  Prof-school|  576|
# |      7th-8th|  646|
# |         10th|  933|
# |   Assoc-acdm| 1067|
# |         11th| 1175|
# |    Assoc-voc| 1382|
# |      Masters| 1723|
# |    Bachelors| 5355|
# | Some-college| 7291|
# |      HS-grad|10501|
# +-------------+-----+

# %% [markdown]
# # Describe the data
# To get a summary statistics, of the data, you can use describe(). It will compute the :
#
# count
# mean
# standarddeviation
# min
# max

# %%
df.describe().show()
# Out:
# +-------+------------------+------------+------------------+-------------+-----------------+--------------+-----------------+------------+-------------------+-------+------------------+----------------+------------------+--------------+------+
# |summary|               age|   workclass|            fnlwgt|    education|    education_num|marital_status|       occupation|relationship|               race|    sex|      capital-gain|    capital-loss|  wrk_hrs_per_week|native_country|income|
# +-------+------------------+------------+------------------+-------------+-----------------+--------------+-----------------+------------+-------------------+-------+------------------+----------------+------------------+--------------+------+
# |  count|             32561|       32561|             32561|        32561|            32561|         32561|            32561|       32561|              32561|  32561|             32561|           32561|             32561|         32561| 32561|
# |   mean| 38.58164675532078|        null|189778.36651208502|         null| 10.0806793403151|          null|             null|        null|               null|   null|1077.6488437087312| 87.303829734959|40.437455852092995|          null|  null|
# | stddev|13.640432553581356|        null|105549.97769702227|         null|2.572720332067397|          null|             null|        null|               null|   null| 7385.292084840354|402.960218649002|12.347428681731838|          null|  null|
# |    min|                17|           ?|             12285|         10th|                1|      Divorced|                ?|     Husband| Amer-Indian-Eskimo| Female|                 0|               0|                 1|             ?| <=50K|
# |    max|                90| Without-pay|           1484705| Some-college|               16|       Widowed| Transport-moving|        Wife|              White|   Male|             99999|            4356|                99|    Yugoslavia|  >50K|
# +-------+------------------+------------+------------------+-------------+-----------------+--------------+-----------------+------------+-------------------+-------+------------------+----------------+------------------+--------------+------+

# %%
# !pip install pandas  --- No need to install second time; it is installed already

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext

#sc = SparkContext()
sc = pyspark.SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

# %%
sconf = SparkConf()
conf = (SparkConf().set("spark.executor.memory", "12g")
       .set("spark.num.executors","5"))

# %%
from datetime import datetime
import time

start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


path="F:\\nycflights_sample\\airOT198710.csv"


df=sqlContext.read.format("csv").option("header","true").option("inferSchema","true").load(path)

ti=(time.time() - start_time)
print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("End Time =", current_time)
# Out:
# Start Time = 09:32:57
# --- 0.0 Minutes,   13.679883241653442 Seconds
# End Time = 09:33:11

# %%
# NO NEED TO RUN THIS WHEN WE WANT TO RUN JUST ONE SAMPLE FILE

# Reading from external USB harddrive or internal hard drive; almost same time..! But subseqent works are faster
# when read from D:\

from datetime import datetime
import time

start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


#path="F:\\nycflights\\AirOnTimeCSV\\airOT201212.csv"

path="D:\\nycflights\\AirOnTimeCSV"

dfSample=sqlContext.read.format("csv").option("header","true").option("inferSchema","true").load(path)

ti=(time.time() - start_time)
print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("End Time =", current_time)

# %%
df.printSchema()
# Out:
# root
#  |-- YEAR: integer (nullable = true)
#  |-- MONTH: integer (nullable = true)
#  |-- DAY_OF_MONTH: integer (nullable = true)
#  |-- DAY_OF_WEEK: integer (nullable = true)
#  |-- FL_DATE: timestamp (nullable = true)
#  |-- UNIQUE_CARRIER: string (nullable = true)
#  |-- TAIL_NUM: string (nullable = true)
#  |-- FL_NUM: integer (nullable = true)
#  |-- ORIGIN_AIRPORT_ID: integer (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- ORIGIN_STATE_ABR: string (nullable = true)
#  |-- DEST_AIRPORT_ID: integer (nullable = true)
#  |-- DEST: string (nullable = true)
#  |-- DEST_STATE_ABR: string (nullable = true)
#  |-- CRS_DEP_TIME: integer (nullable = true)
#  |-- DEP_TIME: integer (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- DEP_DELAY_NEW: double (nullable = true)
#  |-- DEP_DEL15: double (nullable = true)
#  |-- DEP_DELAY_GROUP: integer (nullable = true)
#  |-- TAXI_OUT: string (nullable = true)
#  |-- WHEELS_OFF: string (nullable = true)
#  |-- WHEELS_ON: string (nullable = true)
#  |-- TAXI_IN: string (nullable = true)
#  |-- CRS_ARR_TIME: integer (nullable = true)
#  |-- ARR_TIME: integer (nullable = true)
#  |-- ARR_DELAY: double (nullable = true)
#  |-- ARR_DELAY_NEW: double (nullable = true)
#  |-- ARR_DEL15: double (nullable = true)
#  |-- ARR_DELAY_GROUP: integer (nullable = true)
#  |-- CANCELLED: double (nullable = true)
#  |-- CANCELLATION_CODE: string (nullable = true)
#  |-- DIVERTED: double (nullable = true)
#  |-- CRS_ELAPSED_TIME: double (nullable = true)
#  |-- ACTUAL_ELAPSED_TIME: double (nullable = true)
#  |-- AIR_TIME: string (nullable = true)
#  |-- FLIGHTS: double (nullable = true)
#  |-- DISTANCE: double (nullable = true)
#  |-- DISTANCE_GROUP: integer (nullable = true)
#  |-- CARRIER_DELAY: string (nullable = true)
#  |-- WEATHER_DELAY: string (nullable = true)
#  |-- NAS_DELAY: string (nullable = true)
#  |-- SECURITY_DELAY: string (nullable = true)
#  |-- LATE_AIRCRAFT_DELAY: string (nullable = true)
#  |-- _c44: string (nullable = true)

# %%
df.show()
# Out:
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# |YEAR|MONTH|DAY_OF_MONTH|DAY_OF_WEEK|            FL_DATE|UNIQUE_CARRIER|TAIL_NUM|FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN|ORIGIN_STATE_ABR|DEST_AIRPORT_ID|DEST|DEST_STATE_ABR|CRS_DEP_TIME|DEP_TIME|DEP_DELAY|DEP_DELAY_NEW|DEP_DEL15|DEP_DELAY_GROUP|TAXI_OUT|WHEELS_OFF|WHEELS_ON|TAXI_IN|CRS_ARR_TIME|ARR_TIME|ARR_DELAY|ARR_DELAY_NEW|ARR_DEL15|ARR_DELAY_GROUP|CANCELLED|CANCELLATION_CODE|DIVERTED|CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|AIR_TIME|FLIGHTS|DISTANCE|DISTANCE_GROUP|CARRIER_DELAY|WEATHER_DELAY|NAS_DELAY|SECURITY_DELAY|LATE_AIRCRAFT_DELAY|_c44|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# |1987|   10|           1|          4|1987-10-01 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1117|    -35.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           2|          5|1987-10-02 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1137|    -15.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              336.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           3|          6|1987-10-03 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1111|    -41.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              312.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           4|          7|1987-10-04 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1116|    -36.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           5|          1|1987-10-05 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1119|    -33.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              317.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           6|          2|1987-10-06 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    null|     null|         null|     null|           null|      0.0|             null|     1.0|           352.0|               null|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           7|          3|1987-10-07 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1131|    -21.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              330.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           8|          4|1987-10-08 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1140|    -12.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              338.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           9|          5|1987-10-09 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     910|     10.0|         10.0|      0.0|              0|    null|      null|     null|   null|        1152|    1150|     -2.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              340.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          10|          6|1987-10-10 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     906|      6.0|          6.0|      0.0|              0|    null|      null|     null|   null|        1152|    1152|      0.0|          0.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              346.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          11|          7|1987-10-11 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1200|      8.0|          8.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              358.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          12|          1|1987-10-12 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1157|      5.0|          5.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              358.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          13|          2|1987-10-13 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1145|     -7.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              346.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          14|          3|1987-10-14 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1135|    -17.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              333.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          15|          4|1987-10-15 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1140|    -12.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              340.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          16|          5|1987-10-16 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1123|    -29.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              323.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          17|          6|1987-10-17 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1136|    -16.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              335.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          18|          7|1987-10-18 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1148|     -4.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              347.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          19|          1|1987-10-19 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1152|      0.0|          0.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              352.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          20|          2|1987-10-20 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1154|      2.0|          2.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              352.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# only showing top 20 rows

# %%
#### --------------Start program

start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)

#### -------------Main program

d1Count=df.count()
print('Number of records', d1Count)

#### -------------End program
ti=(time.time() - start_time)
now=datetime.now()
current_time = now.strftime("%H:%M:%S")

print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))
print("End Time =", current_time)
# Out:
# Start Time = 09:34:20
# Number of records 448620
# --- 0.0 Minutes,   1.1349124908447266 Seconds
# End Time = 09:34:21

# %%
#### --------------Start program

start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)

#### -------------Main program

d1Count=df.describe(['ARR_DELAY']).show()

#### -------------End program
ti=(time.time() - start_time)
now=datetime.now()
current_time = now.strftime("%H:%M:%S")

print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))
print("End Time =", current_time)
# Out:
# Start Time = 09:35:50
# +-------+------------------+
# |summary|         ARR_DELAY|
# +-------+------------------+
# |  count|            444780|
# |   mean| 6.004721435316336|
# | stddev|18.558215850110173|
# |    min|           -1295.0|
# |    max|             860.0|
# +-------+------------------+
#
# --- 0.0 Minutes,   2.7094717025756836 Seconds
# End Time = 09:35:53

# %%
df.toPandas() 

## We are able to get 4 times sophisticated information values with less time than just using 'count'
## function; USE ALWAYS NATIVE FUNCTIONS THAT ARE OPTIMIZED FOR CERTAIN COMPUTATIONS. 

## (On a side note, one might think that 'count' function is a foundational native function, 
## meaning it should be superfast)
# Out:
#         YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK    FL_DATE UNIQUE_CARRIER  \
# 0       1987     10             1            4 1987-10-01             AA
# 1       1987     10             2            5 1987-10-02             AA
# 2       1987     10             3            6 1987-10-03             AA
# 3       1987     10             4            7 1987-10-04             AA
# 4       1987     10             5            1 1987-10-05             AA
# 5       1987     10             6            2 1987-10-06             AA
# 6       1987     10             7            3 1987-10-07             AA
# 7       1987     10             8            4 1987-10-08             AA
# 8       1987     10             9            5 1987-10-09             AA
# 9       1987     10            10            6 1987-10-10             AA
# 10      1987     10            11            7 1987-10-11             AA
# 11      1987     10            12            1 1987-10-12             AA
# 12      1987     10            13            2 1987-10-13             AA
# 13      1987     10            14            3 1987-10-14             AA
# 14      1987     10            15            4 1987-10-15             AA
# 15      1987     10            16            5 1987-10-16             AA
# 16      1987     10            17            6 1987-10-17             AA
# 17      1987     10            18            7 1987-10-18             AA
# 18      1987     10            19            1 1987-10-19             AA
# 19      1987     10            20            2 1987-10-20             AA
# 20      1987     10            21            3 1987-10-21             AA
# 21      1987     10            22            4 1987-10-22             AA
# 22      1987     10            23            5 1987-10-23             AA
# 23      1987     10            24            6 1987-10-24             AA
# 24      1987     10            25            7 1987-10-25             AA
# 25      1987     10            26            1 1987-10-26             AA
# 26      1987     10            27            2 1987-10-27             AA
# 27      1987     10            28            3 1987-10-28             AA
# 28      1987     10            29            4 1987-10-29             AA
# 29      1987     10            30            5 1987-10-30             AA
# ...      ...    ...           ...          ...        ...            ...
# 448590  1987     10            25            7 1987-10-25             WN
# 448591  1987     10            26            1 1987-10-26             WN
# 448592  1987     10            27            2 1987-10-27             WN
# 448593  1987     10            28            3 1987-10-28             WN
# 448594  1987     10            29            4 1987-10-29             WN
# 448595  1987     10            30            5 1987-10-30             WN
# 448596  1987     10             1            4 1987-10-01             WN
# 448597  1987     10             2            5 1987-10-02             WN
# 448598  1987     10             4            7 1987-10-04             WN
# 448599  1987     10             5            1 1987-10-05             WN
# 448600  1987     10             6            2 1987-10-06             WN
# 448601  1987     10             7            3 1987-10-07             WN
# 448602  1987     10             9            5 1987-10-09             WN
# 448603  1987     10            11            7 1987-10-11             WN
# 448604  1987     10            12            1 1987-10-12             WN
# 448605  1987     10            13            2 1987-10-13             WN
# 448606  1987     10            14            3 1987-10-14             WN
# 448607  1987     10            15            4 1987-10-15             WN
# 448608  1987     10            16            5 1987-10-16             WN
# 448609  1987     10            18            7 1987-10-18             WN
# 448610  1987     10            19            1 1987-10-19             WN
# 448611  1987     10            20            2 1987-10-20             WN
# 448612  1987     10            21            3 1987-10-21             WN
# 448613  1987     10            22            4 1987-10-22             WN
# 448614  1987     10            25            7 1987-10-25             WN
# 448615  1987     10            26            1 1987-10-26             WN
# 448616  1987     10            27            2 1987-10-27             WN
# 448617  1987     10            28            3 1987-10-28             WN
# 448618  1987     10            29            4 1987-10-29             WN
# 448619  1987     10            30            5 1987-10-30             WN
#
#        TAIL_NUM  FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  ...  AIR_TIME  FLIGHTS  \
# 0          None       1              12478    JFK  ...      None      1.0
# 1          None       1              12478    JFK  ...      None      1.0
# 2          None       1              12478    JFK  ...      None      1.0
# 3          None       1              12478    JFK  ...      None      1.0
# 4          None       1              12478    JFK  ...      None      1.0
# 5          None       1              12478    JFK  ...      None      1.0
# 6          None       1              12478    JFK  ...      None      1.0
# 7          None       1              12478    JFK  ...      None      1.0
# 8          None       1              12478    JFK  ...      None      1.0
# 9          None       1              12478    JFK  ...      None      1.0
# 10         None       1              12478    JFK  ...      None      1.0
# 11         None       1              12478    JFK  ...      None      1.0
# 12         None       1              12478    JFK  ...      None      1.0
# 13         None       1              12478    JFK  ...      None      1.0
# 14         None       1              12478    JFK  ...      None      1.0
# 15         None       1              12478    JFK  ...      None      1.0
# 16         None       1              12478    JFK  ...      None      1.0
# 17         None       1              12478    JFK  ...      None      1.0
# 18         None       1              12478    JFK  ...      None      1.0
# 19         None       1              12478    JFK  ...      None      1.0
# 20         None       1              12478    JFK  ...      None      1.0
# 21         None       1              12478    JFK  ...      None      1.0
# 22         None       1              12478    JFK  ...      None      1.0
# 23         None       1              12478    JFK  ...      None      1.0
# 24         None       1              12478    JFK  ...      None      1.0
# 25         None       1              12478    JFK  ...      None      1.0
# 26         None       1              12478    JFK  ...      None      1.0
# 27         None       1              12478    JFK  ...      None      1.0
# 28         None       1              12478    JFK  ...      None      1.0
# 29         None       1              12478    JFK  ...      None      1.0
# ...         ...     ...                ...    ...  ...       ...      ...
# 448590     None     997              12889    LAS  ...      None      1.0
# 448591     None     997              12889    LAS  ...      None      1.0
# 448592     None     997              12889    LAS  ...      None      1.0
# 448593     None     997              12889    LAS  ...      None      1.0
# 448594     None     997              12889    LAS  ...      None      1.0
# 448595     None     997              12889    LAS  ...      None      1.0
# 448596     None     997              14107    PHX  ...      None      1.0
# 448597     None     997              14107    PHX  ...      None      1.0
# 448598     None     997              14107    PHX  ...      None      1.0
# 448599     None     997              14107    PHX  ...      None      1.0
# 448600     None     997              14107    PHX  ...      None      1.0
# 448601     None     997              14107    PHX  ...      None      1.0
# 448602     None     997              14107    PHX  ...      None      1.0
# 448603     None     997              14107    PHX  ...      None      1.0
# 448604     None     997              14107    PHX  ...      None      1.0
# 448605     None     997              14107    PHX  ...      None      1.0
# 448606     None     997              14107    PHX  ...      None      1.0
# 448607     None     997              14107    PHX  ...      None      1.0
# 448608     None     997              14107    PHX  ...      None      1.0
# 448609     None     997              14107    PHX  ...      None      1.0
# 448610     None     997              14107    PHX  ...      None      1.0
# 448611     None     997              14107    PHX  ...      None      1.0
# 448612     None     997              14107    PHX  ...      None      1.0
# 448613     None     997              14107    PHX  ...      None      1.0
# 448614     None     997              14107    PHX  ...      None      1.0
# 448615     None     997              14107    PHX  ...      None      1.0
# 448616     None     997              14107    PHX  ...      None      1.0
# 448617     None     997              14107    PHX  ...      None      1.0
# 448618     None     997              14107    PHX  ...      None      1.0
# 448619     None     997              14107    PHX  ...      None      1.0
#
#        DISTANCE DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0        2475.0             10           None           None       None
# 1        2475.0             10           None           None       None
# 2        2475.0             10           None           None       None
# 3        2475.0             10           None           None       None
# 4        2475.0             10           None           None       None
# 5        2475.0             10           None           None       None
# 6        2475.0             10           None           None       None
# 7        2475.0             10           None           None       None
# 8        2475.0             10           None           None       None
# 9        2475.0             10           None           None       None
# 10       2475.0             10           None           None       None
# 11       2475.0             10           None           None       None
# 12       2475.0             10           None           None       None
# 13       2475.0             10           None           None       None
# 14       2475.0             10           None           None       None
# 15       2475.0             10           None           None       None
# 16       2475.0             10           None           None       None
# 17       2475.0             10           None           None       None
# 18       2475.0             10           None           None       None
# 19       2475.0             10           None           None       None
# 20       2475.0             10           None           None       None
# 21       2475.0             10           None           None       None
# 22       2475.0             10           None           None       None
# 23       2475.0             10           None           None       None
# 24       2475.0             10           None           None       None
# 25       2475.0             10           None           None       None
# 26       2475.0             10           None           None       None
# 27       2475.0             10           None           None       None
# 28       2475.0             10           None           None       None
# 29       2475.0             10           None           None       None
# ...         ...            ...            ...            ...        ...
# 448590    255.0              2           None           None       None
# 448591    255.0              2           None           None       None
# 448592    255.0              2           None           None       None
# 448593    255.0              2           None           None       None
# 448594    255.0              2           None           None       None
# 448595    255.0              2           None           None       None
# 448596    347.0              2           None           None       None
# 448597    347.0              2           None           None       None
# 448598    347.0              2           None           None       None
# 448599    347.0              2           None           None       None
# 448600    347.0              2           None           None       None
# 448601    347.0              2           None           None       None
# 448602    347.0              2           None           None       None
# 448603    347.0              2           None           None       None
# 448604    347.0              2           None           None       None
# 448605    347.0              2           None           None       None
# 448606    347.0              2           None           None       None
# 448607    347.0              2           None           None       None
# 448608    347.0              2           None           None       None
# 448609    347.0              2           None           None       None
# 448610    347.0              2           None           None       None
# 448611    347.0              2           None           None       None
# 448612    347.0              2           None           None       None
# 448613    347.0              2           None           None       None
# 448614    347.0              2           None           None       None
# 448615    347.0              2           None           None       None
# 448616    347.0              2           None           None       None
# 448617    347.0              2           None           None       None
# 448618    347.0              2           None           None       None
# 448619    347.0              2           None           None       None
#
#         SECURITY_DELAY  LATE_AIRCRAFT_DELAY  _c44
# 0                 None                 None  None
# 1                 None                 None  None
# 2                 None                 None  None
# 3                 None                 None  None
# 4                 None                 None  None
# 5                 None                 None  None
# 6                 None                 None  None
# 7                 None                 None  None
# 8                 None                 None  None
# 9                 None                 None  None
# 10                None                 None  None
# 11                None                 None  None
# 12                None                 None  None
# 13                None                 None  None
# 14                None                 None  None
# 15                None                 None  None
# 16                None                 None  None
# 17                None                 None  None
# 18                None                 None  None
# 19                None                 None  None
# 20                None                 None  None
# 21                None                 None  None
# 22                None                 None  None
# 23                None                 None  None
# 24                None                 None  None
# 25                None                 None  None
# 26                None                 None  None
# 27                None                 None  None
# 28                None                 None  None
# 29                None                 None  None
# ...                ...                  ...   ...
# 448590            None                 None  None
# 448591            None                 None  None
# 448592            None                 None  None
# 448593            None                 None  None
# 448594            None                 None  None
# 448595            None                 None  None
# 448596            None                 None  None
# 448597            None                 None  None
# 448598            None                 None  None
# 448599            None                 None  None
# 448600            None                 None  None
# 448601            None                 None  None
# 448602            None                 None  None
# 448603            None                 None  None
# 448604            None                 None  None
# 448605            None                 None  None
# 448606            None                 None  None
# 448607            None                 None  None
# 448608            None                 None  None
# 448609            None                 None  None
# 448610            None                 None  None
# 448611            None                 None  None
# 448612            None                 None  None
# 448613            None                 None  None
# 448614            None                 None  None
# 448615            None                 None  None
# 448616            None                 None  None
# 448617            None                 None  None
# 448618            None                 None  None
# 448619            None                 None  None
#
# [448620 rows x 45 columns]

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
## Let us see how partitions are used - as of now, my research points there is no way you can get that information 
## from data frame.  So convert it to RDD and get that information

# %% [markdown]
# #### A quick note on how to repartition in increasing or decreasing partitions

# %%
dfrdd=df.rdd     
# quick and easy way to convert a df into rdd; takes a second

# %%
dfrdd.getNumPartitions()
# Out:
# 4

# %%
df.rdd.getNumPartitions()
# Out:
# 4

# %%
dfrdd=dfrdd.repartition(310)

# %%
dfrdd.getNumPartitions()
# Out:
# 310

# %%
## If filtering reduces large data set to a small dataset, the small data set can work on smaller number of 
## partitions and to repartition to lower levels, use function 'coalesc(lower_num)' to get efficient computations
## with out the full reshuffle(If you use repartition function with lower number of partitions, it will do a full
## reshuffle)

# %% [markdown]
# Spark Dataframes
# The key data type used in PySpark is the Spark dataframe. This object can be thought of as a table distributed across a cluster and has functionality that is similar to dataframes in R and Pandas. If you want to do distributed computation using PySpark, then you’ll need to perform operations on Spark dataframes, and not other python data types.
# It is also possible to use Pandas dataframes when using Spark, by calling toPandas() on a Spark dataframe, which returns a pandas object. However, this function should generally be avoided except when working with small dataframes, because it pulls the entire object into memory on a single node.

# %% [markdown]
# ### data frame is better when working with structured
# ### super large data

# %%
# to  release resources from rdd, to detach
dfrdd.unpersist()
# Out:
# MapPartitionsRDD[93] at coalesce at NativeMethodAccessorImpl.java:0

# %%
#How many cores are used as executor


executor_count = len(sc._jsc.sc().statusTracker().getExecutorInfos()) - 1
cores_per_executor = int(sc.getConf().get('spark.executor.cores','1'))

print(executor_count)
print(cores_per_executor)
# Out:
# 0
# 1

# %% [markdown]
# ## Most of the times the common sql outputs involve the verbs
#
# #### select
# #### groupby
# #### having
# #### order
# #### applying aggregation functions
#
# #### The most common aggregation functions are count, mean, min, max, percentiles of some cut (like p1, p5, p10, p25, p50, p75, p90, p95, p99, outliers, standard deviation, median)
#
# #### These and more are available in agg functions.
#
# ## In describe function used below as example, the percentiles, outliers (list), and median are not standard outputs.

# %%
### ---------------data frame is better when working with structured 
### super large data


start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)

#### -------------Main program

dfDescribe=df.describe()


#### -------------End program
ti=(time.time() - start_time)
now=datetime.now()
current_time = now.strftime("%H:%M:%S")

print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))
print("End Time =", current_time)
# Out:
# Start Time = 09:44:23
# --- 1.0 Minutes,   43.33158850669861 Seconds
# End Time = 09:45:07

# %% [markdown]
# #### Differences in various ways of visually inspecting data summaries:  (1) describe function output, (2) Converting describe function output in pandas format, and directly calling a Pandas data frame, and finally printing a pandas data frame of the describe output

# %%
print(dfDescribe.show(10))
# Out:
# +-------+--------------------+------+-----------------+------------------+--------------+--------+-----------------+------------------+------+----------------+------------------+------+--------------+------------------+------------------+-----------------+------------------+-------------------+-------------------+--------+----------+---------+-------+-----------------+------------------+------------------+------------------+-------------------+--------------------+--------------------+-----------------+--------------------+-----------------+-------------------+--------+-------+-----------------+------------------+-------------+-------------+---------+--------------+-------------------+----+
# |summary|                YEAR| MONTH|     DAY_OF_MONTH|       DAY_OF_WEEK|UNIQUE_CARRIER|TAIL_NUM|           FL_NUM| ORIGIN_AIRPORT_ID|ORIGIN|ORIGIN_STATE_ABR|   DEST_AIRPORT_ID|  DEST|DEST_STATE_ABR|      CRS_DEP_TIME|          DEP_TIME|        DEP_DELAY|     DEP_DELAY_NEW|          DEP_DEL15|    DEP_DELAY_GROUP|TAXI_OUT|WHEELS_OFF|WHEELS_ON|TAXI_IN|     CRS_ARR_TIME|          ARR_TIME|         ARR_DELAY|     ARR_DELAY_NEW|          ARR_DEL15|     ARR_DELAY_GROUP|           CANCELLED|CANCELLATION_CODE|            DIVERTED| CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|AIR_TIME|FLIGHTS|         DISTANCE|    DISTANCE_GROUP|CARRIER_DELAY|WEATHER_DELAY|NAS_DELAY|SECURITY_DELAY|LATE_AIRCRAFT_DELAY|_c44|
# +-------+--------------------+------+-----------------+------------------+--------------+--------+-----------------+------------------+------+----------------+------------------+------+--------------+------------------+------------------+-----------------+------------------+-------------------+-------------------+--------+----------+---------+-------+-----------------+------------------+------------------+------------------+-------------------+--------------------+--------------------+-----------------+--------------------+-----------------+-------------------+--------+-------+-----------------+------------------+-------------+-------------+---------+--------------+-------------------+----+
# |  count|              448620|448620|           448620|            448620|        448620|       0|           448620|            448620|448620|          446664|            448620|448620|        446703|            448620|            445619|           445619|            445619|             445619|             445619|       0|         0|        0|      0|           448620|            444780|            444780|            444780|             444780|              444780|              448620|                0|              448620|           448620|             444780|       0| 448620|           448620|            448620|            0|            0|        0|             0|                  0|   0|
# |   mean|              1987.0|  10.0|15.97350541661094| 4.047692924969907|          null|    null|671.1280616111632| 12767.61632784985|  null|            null| 12766.16433284294|  null|          null|1360.1197895769249|1365.3439440418833|5.057519989048941| 5.423460400027826|0.10921661778335304|0.03443973439193571|    null|      null|     null|   null|1490.320997726361| 1493.210607491344| 6.004721435316336|  8.45423130536445|0.18915418858761635|-0.06206663968703629|0.006689403058267...|             null|0.001870179662074...|99.52620480584905| 100.71135392778453|    null|    1.0|587.8776336320271|2.8250813606170033|         null|         null|     null|          null|               null|null|
# | stddev|8.233647849459686...|   0.0|8.932715623219531|1.9328475479256821|          null|    null|516.8870011546963|1564.1552172922652|  null|            null|1563.1383623855188|  null|          null|471.97912360920407|475.53701846384456| 19.7913362561242|19.362638453269266| 0.3119111516211326|  0.936728927784848|    null|      null|     null|   null|485.4609473848625|492.04750703113444|18.558215850110173|15.523710397205587|0.39163149306623257|  1.1457009823621163| 0.08151484377919099|             null| 0.04320516463408394|60.64661583533222|  60.85058347893263|    null|    0.0|496.5675071952869|1.9538747410848083|         null|         null|     null|          null|               null|null|
# |    min|                1987|    10|                1|                 1|            AA|    null|                1|             10135|   ABE|              AK|             10135|   ABE|            AK|                 1|                 1|           -955.0|               0.0|                0.0|                 -2|    null|      null|     null|   null|                1|                 1|           -1295.0|               0.0|                0.0|                  -2|                 0.0|             null|                 0.0|              0.0|              -23.0|    null|    1.0|              0.0|                 1|         null|         null|     null|          null|               null|null|
# |    max|                1987|    10|               31|                 7|            WN|    null|             4938|             16440|   YUM|              WY|             16440|   YUM|            WY|              2359|              2400|           1434.0|            1434.0|                1.0|                 12|    null|      null|     null|   null|             2400|              2400|             860.0|             860.0|                1.0|                  12|                 1.0|             null|                 1.0|            665.0|              920.0|    null|    1.0|           4983.0|                11|         null|         null|     null|          null|               null|null|
# +-------+--------------------+------+-----------------+------------------+--------------+--------+-----------------+------------------+------+----------------+------------------+------+--------------+------------------+------------------+-----------------+------------------+-------------------+-------------------+--------+----------+---------+-------+-----------------+------------------+------------------+------------------+-------------------+--------------------+--------------------+-----------------+--------------------+-----------------+-------------------+--------+-------+-----------------+------------------+-------------+-------------+---------+--------------+-------------------+----+
#
# None

# %%
import pandas as pd

dfDescribe.toPandas()
# Out:
#   summary                   YEAR   MONTH       DAY_OF_MONTH  \
# 0   count                 448620  448620             448620
# 1    mean                 1987.0    10.0  15.97350541661094
# 2  stddev  8.233647849459686E-14     0.0  8.932715623219531
# 3     min                   1987      10                  1
# 4     max                   1987      10                 31
#
#           DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM             FL_NUM  \
# 0              448620         448620        0             448620
# 1   4.047692924969907           None     None  671.1280616111632
# 2  1.9328475479256821           None     None  516.8870011546963
# 3                   1             AA     None                  1
# 4                   7             WN     None               4938
#
#     ORIGIN_AIRPORT_ID  ORIGIN  ...  AIR_TIME FLIGHTS           DISTANCE  \
# 0              448620  448620  ...         0  448620             448620
# 1   12767.61632784985    None  ...      None     1.0  587.8776336320271
# 2  1564.1552172922652    None  ...      None     0.0  496.5675071952869
# 3               10135     ABE  ...      None     1.0                0.0
# 4               16440     YUM  ...      None     1.0             4983.0
#
#        DISTANCE_GROUP CARRIER_DELAY WEATHER_DELAY NAS_DELAY SECURITY_DELAY  \
# 0              448620             0             0         0              0
# 1  2.8250813606170033          None          None      None           None
# 2  1.9538747410848083          None          None      None           None
# 3                   1          None          None      None           None
# 4                  11          None          None      None           None
#
#   LATE_AIRCRAFT_DELAY  _c44
# 0                   0     0
# 1                None  None
# 2                None  None
# 3                None  None
# 4                None  None
#
# [5 rows x 45 columns]

# %%
df.limit(5).toPandas()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK    FL_DATE UNIQUE_CARRIER TAIL_NUM  \
# 0  1987     10             1            4 1987-10-01             AA     None
# 1  1987     10             2            5 1987-10-02             AA     None
# 2  1987     10             3            6 1987-10-03             AA     None
# 3  1987     10             4            7 1987-10-04             AA     None
# 4  1987     10             5            1 1987-10-05             AA     None
#
#    FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  ...  AIR_TIME  FLIGHTS DISTANCE  \
# 0       1              12478    JFK  ...      None      1.0   2475.0
# 1       1              12478    JFK  ...      None      1.0   2475.0
# 2       1              12478    JFK  ...      None      1.0   2475.0
# 3       1              12478    JFK  ...      None      1.0   2475.0
# 4       1              12478    JFK  ...      None      1.0   2475.0
#
#   DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0             10           None           None       None            None
# 1             10           None           None       None            None
# 2             10           None           None       None            None
# 3             10           None           None       None            None
# 4             10           None           None       None            None
#
#    LATE_AIRCRAFT_DELAY  _c44
# 0                 None  None
# 1                 None  None
# 2                 None  None
# 3                 None  None
# 4                 None  None
#
# [5 rows x 45 columns]

# %%
df.dtypes
# Out:
# [('YEAR', 'int'),
#  ('MONTH', 'int'),
#  ('DAY_OF_MONTH', 'int'),
#  ('DAY_OF_WEEK', 'int'),
#  ('FL_DATE', 'timestamp'),
#  ('UNIQUE_CARRIER', 'string'),
#  ('TAIL_NUM', 'string'),
#  ('FL_NUM', 'int'),
#  ('ORIGIN_AIRPORT_ID', 'int'),
#  ('ORIGIN', 'string'),
#  ('ORIGIN_STATE_ABR', 'string'),
#  ('DEST_AIRPORT_ID', 'int'),
#  ('DEST', 'string'),
#  ('DEST_STATE_ABR', 'string'),
#  ('CRS_DEP_TIME', 'int'),
#  ('DEP_TIME', 'int'),
#  ('DEP_DELAY', 'double'),
#  ('DEP_DELAY_NEW', 'double'),
#  ('DEP_DEL15', 'double'),
#  ('DEP_DELAY_GROUP', 'int'),
#  ('TAXI_OUT', 'string'),
#  ('WHEELS_OFF', 'string'),
#  ('WHEELS_ON', 'string'),
#  ('TAXI_IN', 'string'),
#  ('CRS_ARR_TIME', 'int'),
#  ('ARR_TIME', 'int'),
#  ('ARR_DELAY', 'double'),
#  ('ARR_DELAY_NEW', 'double'),
#  ('ARR_DEL15', 'double'),
#  ('ARR_DELAY_GROUP', 'int'),
#  ('CANCELLED', 'double'),
#  ('CANCELLATION_CODE', 'string'),
#  ('DIVERTED', 'double'),
#  ('CRS_ELAPSED_TIME', 'double'),
#  ('ACTUAL_ELAPSED_TIME', 'double'),
#  ('AIR_TIME', 'string'),
#  ('FLIGHTS', 'double'),
#  ('DISTANCE', 'double'),
#  ('DISTANCE_GROUP', 'int'),
#  ('CARRIER_DELAY', 'string'),
#  ('WEATHER_DELAY', 'string'),
#  ('NAS_DELAY', 'string'),
#  ('SECURITY_DELAY', 'string'),
#  ('LATE_AIRCRAFT_DELAY', 'string'),
#  ('_c44', 'string')]

# %%
dfDesPD=dfDescribe.toPandas()
dfDesPD
# Out:
#   summary                   YEAR   MONTH       DAY_OF_MONTH  \
# 0   count                 448620  448620             448620
# 1    mean                 1987.0    10.0  15.97350541661094
# 2  stddev  8.233647849459686E-14     0.0  8.932715623219531
# 3     min                   1987      10                  1
# 4     max                   1987      10                 31
#
#           DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM             FL_NUM  \
# 0              448620         448620        0             448620
# 1   4.047692924969907           None     None  671.1280616111632
# 2  1.9328475479256821           None     None  516.8870011546963
# 3                   1             AA     None                  1
# 4                   7             WN     None               4938
#
#     ORIGIN_AIRPORT_ID  ORIGIN  ...  AIR_TIME FLIGHTS           DISTANCE  \
# 0              448620  448620  ...         0  448620             448620
# 1   12767.61632784985    None  ...      None     1.0  587.8776336320271
# 2  1564.1552172922652    None  ...      None     0.0  496.5675071952869
# 3               10135     ABE  ...      None     1.0                0.0
# 4               16440     YUM  ...      None     1.0             4983.0
#
#        DISTANCE_GROUP CARRIER_DELAY WEATHER_DELAY NAS_DELAY SECURITY_DELAY  \
# 0              448620             0             0         0              0
# 1  2.8250813606170033          None          None      None           None
# 2  1.9538747410848083          None          None      None           None
# 3                   1          None          None      None           None
# 4                  11          None          None      None           None
#
#   LATE_AIRCRAFT_DELAY  _c44
# 0                   0     0
# 1                None  None
# 2                None  None
# 3                None  None
# 4                None  None
#
# [5 rows x 45 columns]

# %%
dfDesPD['summary']
# Out:
# 0     count
# 1      mean
# 2    stddev
# 3       min
# 4       max
# Name: summary, dtype: object

# %%
print('Maximum of DAY_OF_WEEK =',dfDesPD.loc[4,"DAY_OF_WEEK"])
      
print('Maximum of DAY_OF_MONTH =',dfDesPD.loc[4,"DAY_OF_MONTH"])

print('Maximum Carrier Delay in Minutes =',dfDesPD.loc[4,"CARRIER_DELAY"])
# Out:
# Maximum of DAY_OF_WEEK = 7
# Maximum of DAY_OF_MONTH = 31
# Maximum Carrier Delay in Minutes = None

# %%
## A real problem will involve interesting cases like:
## Which carriers - Airlines that are in the top 10 worst delays by month and year
## Let us create output for this

# %%
from pyspark.ml.stat import Summarizer
from pyspark.sql import Row 
from pyspark.ml.linalg import Vectors
start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)

#### -------------Main program



#### -------------End program
ti=(time.time() - start_time)
now=datetime.now()
current_time = now.strftime("%H:%M:%S")

print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))
print("End Time =", current_time)

# %%
### Using builtin groupby and agg(regate) functions to speed up summarizations

#A set of methods for aggregations on a DataFrame:
#
#    agg
#    avg  (mean is also available)
#    count
#    max
#    mean
#    min
#    pivot
#    sum

# %%
#### Using pyspark dataframe  

start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


from pyspark.sql.functions import mean, min, max
#df.select([mean('CRS_ELAPSED_TIME'), min('CRS_ELAPSED_TIME'), max('CRS_ELAPSED_TIME')])


#df.groupBy("YEAR","Month","UNIQUE_CARRIER")
dfSample1=df.groupBy("YEAR","Month","UNIQUE_CARRIER").agg({'ARR_DELAY':'max'}).sort(['max(ARR_DELAY)'], ascending=False).show(20, False)


#dfgroupedAgg=grouped.agg({'ARR_DELAY':'max'})
#dfgroupedAggPD=dfgroupedAgg.toPandas
ti=(time.time() - start_time)

print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

print("End Time =", current_time)
# Out:
# Start Time = 09:49:08
# +----+-----+--------------+--------------+
# |YEAR|Month|UNIQUE_CARRIER|max(ARR_DELAY)|
# +----+-----+--------------+--------------+
# |1987|10   |HP            |860.0         |
# |1987|10   |CO            |800.0         |
# |1987|10   |PS            |769.0         |
# |1987|10   |AA            |726.0         |
# |1987|10   |PA (1)        |687.0         |
# |1987|10   |EA            |542.0         |
# |1987|10   |DL            |412.0         |
# |1987|10   |NW            |359.0         |
# |1987|10   |UA            |327.0         |
# |1987|10   |PI            |277.0         |
# |1987|10   |AS            |270.0         |
# |1987|10   |TW            |220.0         |
# |1987|10   |US            |208.0         |
# |1987|10   |WN            |152.0         |
# +----+-----+--------------+--------------+
#
# --- 0.0 Minutes,   4.770625114440918 Seconds
# End Time = 09:49:08

# %%
## select, filter, mutate, summarize, and arrange(sort) 
## dropna and fillna are two special functions for data science subsequently adopted by SQL

# %%
df_NumColumns=[item[0] for item in df.dtypes if item[1].startswith('string')]
df_NumColumns
# Out:
# ['UNIQUE_CARRIER',
#  'TAIL_NUM',
#  'ORIGIN',
#  'ORIGIN_STATE_ABR',
#  'DEST',
#  'DEST_STATE_ABR',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CANCELLATION_CODE',
#  'AIR_TIME',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  '_c44']

# %%
df.dtypes
# Out:
# [('YEAR', 'int'),
#  ('MONTH', 'int'),
#  ('DAY_OF_MONTH', 'int'),
#  ('DAY_OF_WEEK', 'int'),
#  ('FL_DATE', 'timestamp'),
#  ('UNIQUE_CARRIER', 'string'),
#  ('TAIL_NUM', 'string'),
#  ('FL_NUM', 'int'),
#  ('ORIGIN_AIRPORT_ID', 'int'),
#  ('ORIGIN', 'string'),
#  ('ORIGIN_STATE_ABR', 'string'),
#  ('DEST_AIRPORT_ID', 'int'),
#  ('DEST', 'string'),
#  ('DEST_STATE_ABR', 'string'),
#  ('CRS_DEP_TIME', 'int'),
#  ('DEP_TIME', 'int'),
#  ('DEP_DELAY', 'double'),
#  ('DEP_DELAY_NEW', 'double'),
#  ('DEP_DEL15', 'double'),
#  ('DEP_DELAY_GROUP', 'int'),
#  ('TAXI_OUT', 'string'),
#  ('WHEELS_OFF', 'string'),
#  ('WHEELS_ON', 'string'),
#  ('TAXI_IN', 'string'),
#  ('CRS_ARR_TIME', 'int'),
#  ('ARR_TIME', 'int'),
#  ('ARR_DELAY', 'double'),
#  ('ARR_DELAY_NEW', 'double'),
#  ('ARR_DEL15', 'double'),
#  ('ARR_DELAY_GROUP', 'int'),
#  ('CANCELLED', 'double'),
#  ('CANCELLATION_CODE', 'string'),
#  ('DIVERTED', 'double'),
#  ('CRS_ELAPSED_TIME', 'double'),
#  ('ACTUAL_ELAPSED_TIME', 'double'),
#  ('AIR_TIME', 'string'),
#  ('FLIGHTS', 'double'),
#  ('DISTANCE', 'double'),
#  ('DISTANCE_GROUP', 'int'),
#  ('CARRIER_DELAY', 'string'),
#  ('WEATHER_DELAY', 'string'),
#  ('NAS_DELAY', 'string'),
#  ('SECURITY_DELAY', 'string'),
#  ('LATE_AIRCRAFT_DELAY', 'string'),
#  ('_c44', 'string')]

# %%
df_CatColumns=list(set(df.columns)-set(df_NumColumns))
df_CatColumns
# Out:
# ['FLIGHTS',
#  'ARR_DEL15',
#  'DAY_OF_MONTH',
#  'ACTUAL_ELAPSED_TIME',
#  'DEP_TIME',
#  'DISTANCE_GROUP',
#  'DEP_DEL15',
#  'CRS_DEP_TIME',
#  'DEP_DELAY',
#  'ARR_DELAY_GROUP',
#  'CRS_ELAPSED_TIME',
#  'FL_NUM',
#  'ARR_DELAY',
#  'ORIGIN_AIRPORT_ID',
#  'DEP_DELAY_NEW',
#  'CANCELLED',
#  'DEST_AIRPORT_ID',
#  'CRS_ARR_TIME',
#  'DEP_DELAY_GROUP',
#  'DAY_OF_WEEK',
#  'MONTH',
#  'DISTANCE',
#  'YEAR',
#  'ARR_TIME',
#  'FL_DATE',
#  'ARR_DELAY_NEW',
#  'DIVERTED']

# %%
cols1=["YEAR","Month","UNIQUE_CARRIER","TAIL_NUM","FL_NUM"]

df.select(*cols1, 'ARR_DELAY','AIR_TIME').sort('ARR_DELAY','AIR_TIME', ascending=False).show()
# Out:
# +----+-----+--------------+--------+------+---------+--------+
# |YEAR|Month|UNIQUE_CARRIER|TAIL_NUM|FL_NUM|ARR_DELAY|AIR_TIME|
# +----+-----+--------------+--------+------+---------+--------+
# |1987|   10|            HP|    null|   398|    860.0|    null|
# |1987|   10|            CO|    null|   812|    800.0|    null|
# |1987|   10|            PS|    null|  1960|    769.0|    null|
# |1987|   10|            AA|    null|  1045|    726.0|    null|
# |1987|   10|        PA (1)|    null|   429|    687.0|    null|
# |1987|   10|            HP|    null|   398|    638.0|    null|
# |1987|   10|            CO|    null|    20|    592.0|    null|
# |1987|   10|            EA|    null|   614|    542.0|    null|
# |1987|   10|            CO|    null|   963|    540.0|    null|
# |1987|   10|            CO|    null|   634|    521.0|    null|
# |1987|   10|            CO|    null|     6|    505.0|    null|
# |1987|   10|            CO|    null|   712|    499.0|    null|
# |1987|   10|            CO|    null|     3|    478.0|    null|
# |1987|   10|        PA (1)|    null|   402|    470.0|    null|
# |1987|   10|            EA|    null|  1630|    463.0|    null|
# |1987|   10|            EA|    null|   618|    454.0|    null|
# |1987|   10|            EA|    null|   287|    432.0|    null|
# |1987|   10|            EA|    null|   960|    428.0|    null|
# |1987|   10|            DL|    null|   292|    412.0|    null|
# |1987|   10|            CO|    null|   894|    409.0|    null|
# +----+-----+--------------+--------+------+---------+--------+
# only showing top 20 rows

# %%
df.filter(df.UNIQUE_CARRIER=='AA').show()
# Out:
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# |YEAR|MONTH|DAY_OF_MONTH|DAY_OF_WEEK|            FL_DATE|UNIQUE_CARRIER|TAIL_NUM|FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN|ORIGIN_STATE_ABR|DEST_AIRPORT_ID|DEST|DEST_STATE_ABR|CRS_DEP_TIME|DEP_TIME|DEP_DELAY|DEP_DELAY_NEW|DEP_DEL15|DEP_DELAY_GROUP|TAXI_OUT|WHEELS_OFF|WHEELS_ON|TAXI_IN|CRS_ARR_TIME|ARR_TIME|ARR_DELAY|ARR_DELAY_NEW|ARR_DEL15|ARR_DELAY_GROUP|CANCELLED|CANCELLATION_CODE|DIVERTED|CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|AIR_TIME|FLIGHTS|DISTANCE|DISTANCE_GROUP|CARRIER_DELAY|WEATHER_DELAY|NAS_DELAY|SECURITY_DELAY|LATE_AIRCRAFT_DELAY|_c44|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# |1987|   10|           1|          4|1987-10-01 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1117|    -35.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           2|          5|1987-10-02 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1137|    -15.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              336.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           3|          6|1987-10-03 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1111|    -41.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              312.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           4|          7|1987-10-04 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1116|    -36.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           5|          1|1987-10-05 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1119|    -33.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              317.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           6|          2|1987-10-06 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    null|     null|         null|     null|           null|      0.0|             null|     1.0|           352.0|               null|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           7|          3|1987-10-07 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1131|    -21.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              330.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           8|          4|1987-10-08 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1140|    -12.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              338.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           9|          5|1987-10-09 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     910|     10.0|         10.0|      0.0|              0|    null|      null|     null|   null|        1152|    1150|     -2.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              340.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          10|          6|1987-10-10 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     906|      6.0|          6.0|      0.0|              0|    null|      null|     null|   null|        1152|    1152|      0.0|          0.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              346.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          11|          7|1987-10-11 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1200|      8.0|          8.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              358.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          12|          1|1987-10-12 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1157|      5.0|          5.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              358.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          13|          2|1987-10-13 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1145|     -7.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              346.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          14|          3|1987-10-14 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1135|    -17.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              333.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          15|          4|1987-10-15 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1140|    -12.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              340.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          16|          5|1987-10-16 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1123|    -29.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              323.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          17|          6|1987-10-17 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1136|    -16.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              335.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          18|          7|1987-10-18 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1148|     -4.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              347.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          19|          1|1987-10-19 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1152|      0.0|          0.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              352.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|          20|          2|1987-10-20 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1154|      2.0|          2.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              352.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# only showing top 20 rows

# %% [markdown]
# ### Which one to use in pyspark? Apache Spark APIs – RDD, DataFrame, and DataSet comparison
#
# Before starting the comparison between Spark RDD vs DataFrame vs Dataset, let us see RDDs, DataFrame and Datasets in Spark: (https://data-flair.training/blogs/apache-spark-rdd-vs-dataframe-vs-dataset/)
#
#     Spark RDD APIs – An RDD stands for Resilient Distributed Datasets. It is Read-only partition collection of records.
#     RDD is the fundamental data structure of Spark. It allows a programmer to perform in-memory computations on large
#     clusters in a fault-tolerant manner. Thus, speed up the task. object oriented programming and type safety at compile time
#
# #### Works on structured and unstructured data
#
#     Spark Dataframe APIs – Unlike an RDD, data organized into named columns. For example a table in a relational
#     database. It is an immutable distributed collection of data. DataFrame in Spark allows developers to impose
#     a structure onto a distributed collection of data, allowing higher-level abstraction. Follow this link to learn
#     Spark DataFrame in detail. Works on structured and semi-structured data; No type safety at compile time
#
# #### Works on structured and semi-structured data
#
#     Spark Dataset APIs – Datasets in Apache Spark are an extension of DataFrame API which provides type-safe,
#     object-oriented programming interface. Dataset takes advantage of Spark’s Catalyst optimizer by
#     exposing expressions and data fields to a query planner. Follow this link to learn Spark DataSet in detail. Type safety at compile time
#
# #### Works on structured and unstructured data
#
# All of the above data structures can support all essential data sources; however, RDD can work with compute engines native data, such as JDBC

# %%
df.withColumn('ARR_DELAY_In_Hours', df.ARR_DELAY/60).show()  ## Mutating the data frame
# Out:
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+--------------------+
# |YEAR|MONTH|DAY_OF_MONTH|DAY_OF_WEEK|            FL_DATE|UNIQUE_CARRIER|TAIL_NUM|FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN|ORIGIN_STATE_ABR|DEST_AIRPORT_ID|DEST|DEST_STATE_ABR|CRS_DEP_TIME|DEP_TIME|DEP_DELAY|DEP_DELAY_NEW|DEP_DEL15|DEP_DELAY_GROUP|TAXI_OUT|WHEELS_OFF|WHEELS_ON|TAXI_IN|CRS_ARR_TIME|ARR_TIME|ARR_DELAY|ARR_DELAY_NEW|ARR_DEL15|ARR_DELAY_GROUP|CANCELLED|CANCELLATION_CODE|DIVERTED|CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|AIR_TIME|FLIGHTS|DISTANCE|DISTANCE_GROUP|CARRIER_DELAY|WEATHER_DELAY|NAS_DELAY|SECURITY_DELAY|LATE_AIRCRAFT_DELAY|_c44|  ARR_DELAY_In_Hours|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+--------------------+
# |1987|   10|           1|          4|1987-10-01 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1117|    -35.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null| -0.5833333333333334|
# |1987|   10|           2|          5|1987-10-02 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1137|    -15.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              336.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|               -0.25|
# |1987|   10|           3|          6|1987-10-03 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1111|    -41.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              312.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null| -0.6833333333333333|
# |1987|   10|           4|          7|1987-10-04 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1116|    -36.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|                -0.6|
# |1987|   10|           5|          1|1987-10-05 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1119|    -33.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              317.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|               -0.55|
# |1987|   10|           6|          2|1987-10-06 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    null|     null|         null|     null|           null|      0.0|             null|     1.0|           352.0|               null|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|                null|
# |1987|   10|           7|          3|1987-10-07 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1131|    -21.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              330.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|               -0.35|
# |1987|   10|           8|          4|1987-10-08 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1140|    -12.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              338.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|                -0.2|
# |1987|   10|           9|          5|1987-10-09 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     910|     10.0|         10.0|      0.0|              0|    null|      null|     null|   null|        1152|    1150|     -2.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              340.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|-0.03333333333333333|
# |1987|   10|          10|          6|1987-10-10 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     906|      6.0|          6.0|      0.0|              0|    null|      null|     null|   null|        1152|    1152|      0.0|          0.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              346.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|                 0.0|
# |1987|   10|          11|          7|1987-10-11 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1200|      8.0|          8.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              358.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null| 0.13333333333333333|
# |1987|   10|          12|          1|1987-10-12 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1157|      5.0|          5.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              358.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null| 0.08333333333333333|
# |1987|   10|          13|          2|1987-10-13 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1145|     -7.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              346.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|-0.11666666666666667|
# |1987|   10|          14|          3|1987-10-14 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1135|    -17.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              333.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null| -0.2833333333333333|
# |1987|   10|          15|          4|1987-10-15 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1140|    -12.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              340.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|                -0.2|
# |1987|   10|          16|          5|1987-10-16 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1123|    -29.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              323.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|-0.48333333333333334|
# |1987|   10|          17|          6|1987-10-17 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1136|    -16.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              335.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|-0.26666666666666666|
# |1987|   10|          18|          7|1987-10-18 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1148|     -4.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              347.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|-0.06666666666666667|
# |1987|   10|          19|          1|1987-10-19 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1152|      0.0|          0.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              352.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|                 0.0|
# |1987|   10|          20|          2|1987-10-20 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1154|      2.0|          2.0|      0.0|              0|      0.0|             null|     0.0|           352.0|              352.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null| 0.03333333333333333|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+--------------------+
# only showing top 20 rows

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
from pyspark.sql.functions import countDistinct, avg, stddev

avg_cols=['ARR_TIME','ARR_DELAY']
dfg1=df.groupby('YEAR','Month','UNIQUE_CARRIER')
dfg1.min(*avg_cols).show()

dfg1.avg(*avg_cols).show()

dfg1.max(*avg_cols).show()

## Now you can use select/filter/mutate in between the data frame and the summary
## functions such as min, avg, max,
# Out:
# +----+-----+--------------+-------------+--------------+
# |YEAR|Month|UNIQUE_CARRIER|min(ARR_TIME)|min(ARR_DELAY)|
# +----+-----+--------------+-------------+--------------+
# |1987|   10|            CO|            1|        -965.0|
# |1987|   10|        PA (1)|            2|         -42.0|
# |1987|   10|            NW|            1|        -595.0|
# |1987|   10|            TW|            1|       -1295.0|
# |1987|   10|            UA|            1|         -45.0|
# |1987|   10|            US|            1|         -58.0|
# |1987|   10|            PS|            1|         -56.0|
# |1987|   10|            AA|            1|        -258.0|
# |1987|   10|            EA|            1|         -49.0|
# |1987|   10|            PI|            1|         -32.0|
# |1987|   10|            DL|            1|         -71.0|
# |1987|   10|            WN|            1|         -39.0|
# |1987|   10|            HP|            1|         -48.0|
# |1987|   10|            AS|            3|        -720.0|
# +----+-----+--------------+-------------+--------------+
#
# +----+-----+--------------+------------------+------------------+
# |YEAR|Month|UNIQUE_CARRIER|     avg(ARR_TIME)|    avg(ARR_DELAY)|
# +----+-----+--------------+------------------+------------------+
# |1987|   10|            CO|1514.7846045197741|2.0199623352165723|
# |1987|   10|        PA (1)|1576.3538794801102| 6.234344230011816|
# |1987|   10|            NW| 1517.539601692403| 7.854825235130837|
# |1987|   10|            TW| 1519.285684148348|  5.77659170499135|
# |1987|   10|            UA| 1471.687891916543|  5.26454604188044|
# |1987|   10|            US|1493.9439135983068| 7.916648510691275|
# |1987|   10|            PS|1486.3696692470091|17.218156228008446|
# |1987|   10|            AA| 1497.758753049218| 2.437455158559334|
# |1987|   10|            EA| 1497.940011599967| 5.243765017814235|
# |1987|   10|            PI|1500.0775347400927| 5.627097272259393|
# |1987|   10|            DL|1484.6237188172472|  8.16234956563322|
# |1987|   10|            WN|1483.6231229847997| 3.590649470290189|
# |1987|   10|            HP|1401.3690444145357|  9.45006729475101|
# |1987|   10|            AS|1461.3759726962458|10.100887372013652|
# +----+-----+--------------+------------------+------------------+
#
# +----+-----+--------------+-------------+--------------+
# |YEAR|Month|UNIQUE_CARRIER|max(ARR_TIME)|max(ARR_DELAY)|
# +----+-----+--------------+-------------+--------------+
# |1987|   10|            CO|         2359|         800.0|
# |1987|   10|        PA (1)|         2359|         687.0|
# |1987|   10|            NW|         2400|         359.0|
# |1987|   10|            TW|         2359|         220.0|
# |1987|   10|            UA|         2400|         327.0|
# |1987|   10|            US|         2400|         208.0|
# |1987|   10|            PS|         2400|         769.0|
# |1987|   10|            AA|         2400|         726.0|
# |1987|   10|            EA|         2400|         542.0|
# |1987|   10|            PI|         2400|         277.0|
# |1987|   10|            DL|         2400|         412.0|
# |1987|   10|            WN|         2400|         152.0|
# |1987|   10|            HP|         2400|         860.0|
# |1987|   10|            AS|         2400|         270.0|
# +----+-----+--------------+-------------+--------------+

# %%
df.columns
# Out:
# ['YEAR',
#  'MONTH',
#  'DAY_OF_MONTH',
#  'DAY_OF_WEEK',
#  'FL_DATE',
#  'UNIQUE_CARRIER',
#  'TAIL_NUM',
#  'FL_NUM',
#  'ORIGIN_AIRPORT_ID',
#  'ORIGIN',
#  'ORIGIN_STATE_ABR',
#  'DEST_AIRPORT_ID',
#  'DEST',
#  'DEST_STATE_ABR',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_NEW',
#  'DEP_DEL15',
#  'DEP_DELAY_GROUP',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'ARR_DELAY_GROUP',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'FLIGHTS',
#  'DISTANCE',
#  'DISTANCE_GROUP',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  '_c44']

# %%
start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


# Two step approach to groupby and then use agg functions

group_data = df.groupBy("YEAR","Month","UNIQUE_CARRIER")
dfgrouped=group_data.agg({'ARR_DELAY': 'avg', }).show()

dfgrouped=group_data.agg({'ARR_DELAY': 'max', }).show()

ti=(time.time() - start_time)
print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

print("End Time =", current_time)
# Out:
# Start Time = 09:59:58
# +----+-----+--------------+------------------+
# |YEAR|Month|UNIQUE_CARRIER|    avg(ARR_DELAY)|
# +----+-----+--------------+------------------+
# |1987|   10|            CO|2.0199623352165723|
# |1987|   10|        PA (1)| 6.234344230011816|
# |1987|   10|            NW| 7.854825235130837|
# |1987|   10|            TW|  5.77659170499135|
# |1987|   10|            UA|  5.26454604188044|
# |1987|   10|            US| 7.916648510691275|
# |1987|   10|            PS|17.218156228008446|
# |1987|   10|            AA| 2.437455158559334|
# |1987|   10|            EA| 5.243765017814235|
# |1987|   10|            PI| 5.627097272259393|
# |1987|   10|            DL|  8.16234956563322|
# |1987|   10|            WN| 3.590649470290189|
# |1987|   10|            HP|  9.45006729475101|
# |1987|   10|            AS|10.100887372013652|
# +----+-----+--------------+------------------+
#
# +----+-----+--------------+--------------+
# |YEAR|Month|UNIQUE_CARRIER|max(ARR_DELAY)|
# +----+-----+--------------+--------------+
# |1987|   10|            CO|         800.0|
# |1987|   10|        PA (1)|         687.0|
# |1987|   10|            NW|         359.0|
# |1987|   10|            TW|         220.0|
# |1987|   10|            UA|         327.0|
# |1987|   10|            US|         208.0|
# |1987|   10|            PS|         769.0|
# |1987|   10|            AA|         726.0|
# |1987|   10|            EA|         542.0|
# |1987|   10|            PI|         277.0|
# |1987|   10|            DL|         412.0|
# |1987|   10|            WN|         152.0|
# |1987|   10|            HP|         860.0|
# |1987|   10|            AS|         270.0|
# +----+-----+--------------+--------------+
#
# --- 0.0 Minutes,   6.410099506378174 Seconds
# End Time = 09:59:58

# %%
#  Within every year print the top 10 delays of each carrier


## df = spark.createDataFrame([(1, 2, 3)] )
## cols = ["_1", "_2", "_3"]

## df.orderBy(cols, ascending=False)


#### Using pyspark dataframe  

start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


#from pyspark.sql.functions import mean, min, max
#df.select([mean('CRS_ELAPSED_TIME'), min('CRS_ELAPSED_TIME'), max('CRS_ELAPSED_TIME')]).show()

group_data = df.groupBy("YEAR","Month","UNIQUE_CARRIER")

dfgrouped=group_data.agg({'ARR_DELAY':'mean'})




dfgroupedPandas=dfgrouped.toPandas()

ti=(time.time() - start_time)
print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

print("End Time =", current_time)
# Out:
# Start Time = 10:01:05
# --- 0.0 Minutes,   4.097306728363037 Seconds
# End Time = 10:01:05

# %%
start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


from pyspark.sql.functions import mean, min, max
#df.select([mean('CRS_ELAPSED_TIME'), min('CRS_ELAPSED_TIME'), max('CRS_ELAPSED_TIME')]).show()



d1=df.take(10000)
d1p=sc.parallelize(d1)
d1Count=d1p.count()
print(d1Count)

ti=(time.time() - start_time)
print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

now=datetime.now()
print("End Time =", now.strftime("%H:%M:%S"))

# %%
start_time = time.time()
now=datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)


from pyspark.sql.functions import mean, min, max
df.select([mean('CRS_ELAPSED_TIME'), min('CRS_ELAPSED_TIME'), max('CRS_ELAPSED_TIME')]).show()

ti=(time.time() - start_time)
print("--- %s Minutes, " % round(ti/60,0), " %s Seconds" % (ti%60))

print("End Time =", now.strftime("%H:%M:%S"))

# %%
df.dtypes

# %%
pd.set_option('display.max_rows', None)
dfCube1=df.cube(df.YEAR, df.MONTH,df.FL_NUM, df.UNIQUE_CARRIER).count().show(1000,False)
# Out:
# +----+-----+------+--------------+------+
# |YEAR|MONTH|FL_NUM|UNIQUE_CARRIER|count |
# +----+-----+------+--------------+------+
# |1987|10   |195   |AA            |62    |
# |1987|10   |226   |AA            |57    |
# |1987|10   |265   |AA            |92    |
# |1987|10   |303   |AA            |62    |
# |1987|10   |530   |AA            |61    |
# |1987|10   |595   |AA            |30    |
# |1987|10   |973   |AA            |93    |
# |1987|10   |1004  |AA            |60    |
# |1987|10   |1062  |AA            |59    |
# |1987|10   |2183  |AA            |89    |
# |1987|10   |2404  |AA            |31    |
# |1987|10   |174   |US            |60    |
# |1987|10   |279   |US            |86    |
# |1987|10   |395   |AS            |59    |
# |1987|10   |313   |CO            |31    |
# |1987|10   |573   |CO            |54    |
# |null|null |61    |null          |407   |
# |null|null |67    |AA            |62    |
# |null|10   |123   |AA            |58    |
# |null|null |134   |AA            |61    |
# |1987|null |152   |null          |323   |
# |null|null |154   |null          |317   |
# |1987|null |159   |null          |263   |
# |null|10   |202   |AA            |92    |
# |null|null |215   |AA            |60    |
# |1987|null |409   |null          |586   |
# |null|10   |409   |AA            |61    |
# |null|null |426   |null          |482   |
# |null|null |427   |null          |531   |
# |null|null |485   |AA            |60    |
# |null|10   |517   |AA            |59    |
# |null|null |597   |AA            |91    |
# |1987|null |674   |null          |479   |
# |1987|10   |675   |null          |423   |
# |1987|null |675   |null          |423   |
# |1987|10   |803   |null          |466   |
# |1987|null |817   |AA            |60    |
# |null|null |822   |AA            |61    |
# |null|10   |827   |null          |389   |
# |1987|null |834   |AA            |61    |
# |1987|null |852   |AA            |52    |
# |null|null |854   |AA            |60    |
# |null|10   |1003  |null          |255   |
# |1987|null |1039  |null          |115   |
# |1987|10   |1093  |null          |138   |
# |1987|10   |2144  |null          |62    |
# |1987|10   |2273  |null          |26    |
# |null|null |2392  |AA            |25    |
# |null|10   |2512  |AA            |60    |
# |null|10   |39    |US            |30    |
# |null|null |98    |US            |62    |
# |null|10   |102   |US            |61    |
# |null|10   |132   |US            |60    |
# |null|10   |186   |US            |59    |
# |null|10   |240   |US            |61    |
# |1987|null |350   |US            |31    |
# |null|10   |423   |US            |52    |
# |null|null |649   |US            |61    |
# |1987|null |908   |US            |9     |
# |null|null |927   |US            |5     |
# |1987|null |958   |US            |8     |
# |null|10   |980   |US            |5     |
# |null|null |42    |AS            |22    |
# |null|10   |46    |AS            |30    |
# |1987|null |183   |AS            |62    |
# |1987|null |744   |null          |335   |
# |1987|null |15    |CO            |19    |
# |null|10   |127   |CO            |25    |
# |1987|null |315   |CO            |26    |
# |null|null |351   |CO            |31    |
# |null|10   |489   |CO            |34    |
# |null|10   |628   |CO            |20    |
# |1987|null |636   |CO            |59    |
# |null|null |692   |CO            |60    |
# |1987|10   |763   |CO            |28    |
# |1987|10   |1083  |CO            |61    |
# |1987|10   |1291  |CO            |5     |
# |1987|10   |1725  |CO            |58    |
# |1987|10   |52    |DL            |25    |
# |1987|10   |192   |DL            |31    |
# |1987|10   |298   |DL            |60    |
# |1987|10   |520   |DL            |31    |
# |1987|10   |523   |DL            |62    |
# |1987|10   |671   |DL            |93    |
# |1987|10   |1543  |DL            |62    |
# |1987|10   |85    |EA            |76    |
# |1987|10   |466   |EA            |58    |
# |1987|10   |503   |EA            |28    |
# |1987|10   |578   |EA            |57    |
# |1987|10   |602   |EA            |83    |
# |1987|10   |656   |EA            |25    |
# |1987|10   |682   |EA            |55    |
# |1987|10   |776   |EA            |57    |
# |null|null |794   |null          |371   |
# |null|null |808   |CO            |54    |
# |null|10   |833   |CO            |29    |
# |null|null |871   |CO            |50    |
# |1987|10   |1103  |null          |193   |
# |null|null |1119  |CO            |5     |
# |1987|null |1171  |null          |171   |
# |1987|10   |1180  |null          |111   |
# |null|null |1193  |null          |89    |
# |null|10   |1221  |CO            |26    |
# |null|10   |1244  |CO            |45    |
# |1987|null |1622  |null          |199   |
# |1987|null |96    |DL            |54    |
# |null|null |104   |DL            |62    |
# |null|10   |207   |DL            |31    |
# |null|10   |292   |DL            |60    |
# |1987|null |327   |DL            |31    |
# |null|null |339   |DL            |30    |
# |1987|null |372   |DL            |90    |
# |null|10   |383   |DL            |29    |
# |null|10   |534   |DL            |62    |
# |1987|null |645   |DL            |90    |
# |null|null |675   |DL            |57    |
# |null|null |704   |DL            |30    |
# |null|10   |773   |DL            |60    |
# |1987|10   |829   |null          |357   |
# |null|null |840   |DL            |62    |
# |null|null |929   |DL            |30    |
# |1987|null |957   |DL            |61    |
# |null|null |964   |null          |202   |
# |null|10   |1435  |DL            |31    |
# |1987|null |1493  |null          |58    |
# |null|null |1498  |DL            |30    |
# |1987|10   |1564  |null          |130   |
# |null|10   |1566  |null          |117   |
# |null|null |1645  |null          |122   |
# |1987|10   |1667  |null          |104   |
# |null|null |1808  |null          |89    |
# |null|10   |1838  |null          |151   |
# |null|10   |1849  |DL            |92    |
# |null|10   |1949  |DL            |29    |
# |null|null |115   |EA            |29    |
# |null|10   |257   |EA            |29    |
# |1987|null |318   |EA            |29    |
# |null|null |347   |EA            |48    |
# |null|10   |642   |EA            |60    |
# |null|10   |862   |EA            |25    |
# |1987|10   |1988  |EA            |5     |
# |1987|10   |17    |HP            |62    |
# |1987|10   |426   |HP            |58    |
# |1987|10   |1233  |HP            |17    |
# |1987|10   |1259  |HP            |31    |
# |1987|10   |132   |NW            |25    |
# |1987|10   |146   |NW            |58    |
# |1987|10   |1146  |NW            |84    |
# |1987|10   |206   |PA (1)        |53    |
# |1987|10   |539   |PA (1)        |31    |
# |1987|10   |582   |PA (1)        |27    |
# |1987|10   |377   |PI            |61    |
# |1987|10   |390   |PI            |62    |
# |1987|10   |404   |PI            |62    |
# |1987|10   |832   |PI            |62    |
# |1987|10   |949   |PI            |13    |
# |1987|10   |1849  |PS            |1     |
# |null|null |1440  |EA            |31    |
# |null|10   |1840  |EA            |9     |
# |1987|null |418   |HP            |30    |
# |null|10   |475   |HP            |26    |
# |null|10   |644   |HP            |52    |
# |1987|null |1251  |HP            |57    |
# |null|10   |276   |NW            |57    |
# |null|10   |308   |NW            |26    |
# |1987|null |404   |NW            |57    |
# |null|null |475   |NW            |88    |
# |null|null |837   |NW            |54    |
# |null|10   |1121  |NW            |52    |
# |1987|10   |1281  |null          |140   |
# |null|10   |1481  |NW            |31    |
# |1987|null |241   |PA (1)        |22    |
# |null|null |null  |PI            |39228 |
# |1987|null |4     |PI            |60    |
# |null|null |54    |PI            |62    |
# |1987|null |95    |PI            |61    |
# |null|10   |105   |PI            |90    |
# |null|10   |279   |PI            |1     |
# |null|null |295   |PI            |62    |
# |null|null |333   |PI            |52    |
# |null|10   |346   |PI            |64    |
# |null|10   |350   |PI            |62    |
# |null|10   |479   |PI            |44    |
# |null|null |556   |PI            |62    |
# |null|10   |582   |PI            |61    |
# |null|null |795   |PI            |62    |
# |1987|null |1569  |PS            |58    |
# |null|null |1604  |PS            |29    |
# |1987|null |1693  |PS            |23    |
# |1987|10   |1771  |null          |52    |
# |1987|null |1823  |PS            |22    |
# |null|10   |1935  |PS            |55    |
# |1987|null |107   |TW            |29    |
# |null|10   |123   |TW            |66    |
# |1987|10   |345   |TW            |86    |
# |1987|10   |400   |TW            |87    |
# |1987|10   |488   |TW            |59    |
# |1987|10   |614   |TW            |61    |
# |1987|10   |118   |UA            |87    |
# |1987|10   |484   |UA            |61    |
# |1987|10   |704   |UA            |120   |
# |1987|10   |753   |UA            |29    |
# |1987|10   |87    |WN            |44    |
# |1987|10   |164   |WN            |4     |
# |1987|10   |412   |WN            |44    |
# |1987|10   |995   |WN            |51    |
# |null|10   |136   |TW            |62    |
# |null|10   |183   |TW            |49    |
# |null|null |273   |TW            |52    |
# |null|10   |388   |TW            |66    |
# |null|null |505   |TW            |58    |
# |null|null |586   |TW            |46    |
# |1987|null |607   |TW            |4     |
# |1987|null |708   |TW            |59    |
# |1987|null |748   |TW            |23    |
# |null|null |24    |UA            |30    |
# |null|10   |163   |UA            |30    |
# |null|10   |178   |UA            |55    |
# |null|null |224   |UA            |31    |
# |1987|null |276   |UA            |30    |
# |null|10   |294   |UA            |90    |
# |null|null |343   |UA            |58    |
# |null|null |391   |UA            |60    |
# |null|null |426   |UA            |29    |
# |1987|null |427   |UA            |31    |
# |null|10   |585   |UA            |61    |
# |null|10   |610   |UA            |62    |
# |1987|null |673   |UA            |31    |
# |1987|null |740   |UA            |31    |
# |1987|null |820   |UA            |28    |
# |1987|null |849   |UA            |30    |
# |null|10   |964   |UA            |58    |
# |null|10   |987   |UA            |85    |
# |1987|null |1052  |UA            |4     |
# |null|null |1057  |UA            |62    |
# |1987|null |1163  |UA            |31    |
# |1987|null |1452  |UA            |31    |
# |1987|null |1628  |UA            |28    |
# |null|null |4     |WN            |42    |
# |1987|null |91    |WN            |118   |
# |null|10   |602   |WN            |22    |
# |null|null |709   |WN            |49    |
# |null|10   |948   |WN            |133   |
# |1987|10   |207   |AA            |88    |
# |1987|10   |643   |AA            |30    |
# |1987|10   |906   |AA            |30    |
# |1987|10   |1069  |AA            |61    |
# |1987|10   |66    |US            |61    |
# |1987|10   |162   |US            |49    |
# |1987|10   |611   |US            |62    |
# |1987|10   |105   |AS            |26    |
# |1987|10   |316   |CO            |31    |
# |1987|10   |461   |CO            |55    |
# |null|10   |35    |AA            |60    |
# |null|10   |122   |AA            |54    |
# |1987|null |132   |null          |395   |
# |null|null |140   |null          |328   |
# |1987|10   |174   |null          |385   |
# |null|10   |269   |null          |218   |
# |1987|10   |276   |null          |464   |
# |1987|10   |389   |null          |198   |
# |1987|null |425   |null          |473   |
# |null|null |459   |AA            |59    |
# |null|10   |582   |AA            |121   |
# |1987|null |624   |null          |261   |
# |1987|null |661   |AA            |31    |
# |null|10   |854   |AA            |60    |
# |1987|null |939   |AA            |28    |
# |null|null |940   |AA            |61    |
# |null|10   |980   |null          |252   |
# |null|10   |1040  |AA            |61    |
# |1987|null |1049  |null          |234   |
# |null|null |1081  |null          |205   |
# |1987|10   |2044  |null          |26    |
# |1987|null |2162  |AA            |31    |
# |null|10   |2245  |AA            |27    |
# |null|10   |2256  |null          |22    |
# |null|10   |2543  |AA            |61    |
# |null|null |2724  |AA            |59    |
# |1987|null |2763  |null          |60    |
# |1987|null |6     |US            |62    |
# |1987|null |12    |US            |56    |
# |null|10   |45    |null          |255   |
# |null|null |62    |US            |61    |
# |null|10   |228   |US            |31    |
# |null|null |248   |US            |30    |
# |null|10   |251   |US            |25    |
# |null|10   |325   |US            |30    |
# |null|null |346   |US            |62    |
# |null|10   |401   |null          |574   |
# |null|null |431   |US            |61    |
# |null|10   |523   |US            |85    |
# |1987|null |643   |US            |31    |
# |null|10   |188   |AS            |89    |
# |1987|null |740   |AS            |25    |
# |null|10   |740   |null          |373   |
# |null|10   |69    |CO            |10    |
# |null|10   |103   |CO            |59    |
# |1987|null |126   |CO            |58    |
# |null|null |135   |CO            |31    |
# |1987|null |506   |CO            |31    |
# |null|10   |533   |CO            |51    |
# |1987|null |724   |CO            |53    |
# |1987|10   |874   |CO            |61    |
# |1987|10   |1110  |CO            |29    |
# |1987|10   |1681  |CO            |26    |
# |1987|10   |519   |DL            |31    |
# |1987|10   |933   |DL            |61    |
# |1987|10   |1092  |DL            |60    |
# |1987|10   |1946  |DL            |31    |
# |1987|10   |123   |EA            |55    |
# |1987|10   |155   |EA            |61    |
# |1987|10   |627   |EA            |23    |
# |1987|10   |916   |EA            |30    |
# |1987|null |823   |CO            |50    |
# |null|null |1037  |CO            |8     |
# |null|null |1074  |CO            |60    |
# |1987|null |1123  |CO            |44    |
# |1987|null |1128  |CO            |30    |
# |null|null |1299  |null          |178   |
# |null|10   |1601  |null          |134   |
# |null|10   |1605  |null          |139   |
# |null|null |1610  |null          |86    |
# |null|10   |1622  |CO            |59    |
# |1987|10   |1638  |null          |148   |
# |null|null |1643  |null          |199   |
# |1987|10   |1756  |null          |81    |
# |1987|null |1784  |CO            |25    |
# |1987|null |74    |DL            |30    |
# |1987|null |196   |DL            |31    |
# |null|null |205   |DL            |120   |
# |null|10   |387   |DL            |29    |
# |null|null |419   |DL            |85    |
# |null|null |487   |DL            |55    |
# |1987|null |488   |DL            |52    |
# |null|10   |507   |DL            |31    |
# |null|10   |538   |DL            |61    |
# |null|10   |547   |DL            |30    |
# |1987|null |596   |DL            |55    |
# |1987|null |662   |DL            |89    |
# |1987|null |856   |DL            |28    |
# |null|null |877   |null          |211   |
# |null|null |918   |DL            |60    |
# |1987|null |930   |DL            |29    |
# |null|null |1085  |DL            |30    |
# |null|10   |1485  |null          |115   |
# |null|null |1523  |null          |31    |
# |1987|null |1685  |DL            |30    |
# |null|10   |1807  |DL            |60    |
# |1987|10   |1826  |null          |59    |
# |1987|null |1863  |null          |34    |
# |1987|10   |1866  |null          |53    |
# |1987|10   |1919  |null          |53    |
# |null|null |1919  |DL            |29    |
# |null|null |1926  |DL            |28    |
# |null|null |23    |EA            |5     |
# |null|null |219   |EA            |61    |
# |null|null |480   |EA            |25    |
# |1987|null |512   |EA            |44    |
# |1987|null |565   |EA            |30    |
# |null|null |568   |EA            |28    |
# |null|null |589   |EA            |60    |
# |null|null |628   |EA            |30    |
# |1987|null |695   |EA            |58    |
# |null|null |718   |EA            |58    |
# |null|null |721   |EA            |28    |
# |null|10   |743   |EA            |35    |
# |null|null |776   |EA            |57    |
# |1987|null |795   |EA            |55    |
# |1987|null |958   |EA            |78    |
# |1987|10   |1206  |HP            |27    |
# |1987|10   |406   |NW            |29    |
# |1987|10   |433   |NW            |60    |
# |1987|10   |479   |NW            |73    |
# |1987|10   |545   |NW            |28    |
# |1987|10   |104   |PI            |57    |
# |1987|10   |294   |PI            |4     |
# |1987|10   |768   |PI            |30    |
# |1987|10   |796   |PI            |31    |
# |1987|10   |1637  |PS            |28    |
# |1987|10   |77    |TW            |58    |
# |1987|null |1683  |EA            |122   |
# |null|null |28    |HP            |53    |
# |null|10   |176   |HP            |92    |
# |1987|null |650   |HP            |29    |
# |null|10   |1221  |HP            |56    |
# |null|10   |86    |NW            |60    |
# |null|10   |281   |NW            |55    |
# |null|10   |319   |NW            |4     |
# |null|null |355   |NW            |58    |
# |null|null |477   |NW            |29    |
# |1987|null |517   |NW            |21    |
# |1987|null |520   |NW            |20    |
# |null|10   |573   |NW            |30    |
# |1987|null |578   |NW            |31    |
# |null|10   |653   |NW            |31    |
# |1987|null |685   |NW            |51    |
# |1987|null |690   |NW            |57    |
# |null|null |714   |NW            |27    |
# |null|10   |724   |NW            |29    |
# |null|10   |770   |NW            |28    |
# |null|10   |810   |NW            |27    |
# |null|10   |1146  |NW            |84    |
# |null|null |1404  |NW            |29    |
# |null|null |1477  |NW            |36    |
# |1987|null |367   |PA (1)        |29    |
# |1987|null |511   |PA (1)        |28    |
# |null|10   |6     |PI            |61    |
# |null|null |102   |PI            |117   |
# |1987|null |106   |PI            |62    |
# |null|null |107   |PI            |61    |
# |null|10   |273   |PI            |31    |
# |null|10   |320   |PI            |62    |
# |1987|null |453   |PI            |31    |
# |null|10   |456   |PI            |62    |
# |1987|null |503   |PI            |87    |
# |1987|null |725   |PI            |60    |
# |null|null |739   |PI            |148   |
# |null|null |740   |PI            |88    |
# |null|10   |837   |PI            |62    |
# |null|null |884   |PI            |31    |
# |null|10   |891   |PI            |8     |
# |1987|null |901   |PI            |30    |
# |null|10   |1443  |PS            |26    |
# |1987|null |1478  |null          |34    |
# |null|null |1511  |PS            |23    |
# |null|10   |1554  |PS            |25    |
# |null|null |1594  |PS            |10    |
# |null|10   |1604  |PS            |29    |
# |null|null |1670  |PS            |53    |
# |1987|null |1690  |PS            |49    |
# |1987|null |1723  |PS            |77    |
# |null|null |1762  |null          |76    |
# |null|null |1810  |PS            |28    |
# |null|null |1818  |PS            |29    |
# |1987|null |1881  |PS            |22    |
# |null|10   |1977  |PS            |60    |
# |null|null |44    |TW            |57    |
# |1987|10   |732   |TW            |50    |
# |1987|10   |132   |UA            |25    |
# |1987|10   |432   |UA            |25    |
# |1987|10   |565   |UA            |26    |
# |1987|10   |569   |UA            |28    |
# |1987|10   |717   |UA            |121   |
# |1987|10   |769   |UA            |32    |
# |1987|10   |1476  |UA            |114   |
# |1987|10   |1553  |UA            |2     |
# |1987|10   |963   |WN            |154   |
# |null|null |203   |TW            |59    |
# |null|null |345   |TW            |86    |
# |1987|null |804   |TW            |60    |
# |null|null |906   |TW            |58    |
# |null|null |36    |UA            |53    |
# |1987|null |149   |UA            |57    |
# |1987|null |277   |UA            |118   |
# |1987|null |329   |UA            |29    |
# |null|null |341   |UA            |59    |
# |null|null |381   |UA            |62    |
# |null|null |469   |UA            |92    |
# |1987|null |473   |UA            |82    |
# |null|null |538   |UA            |30    |
# |null|null |567   |UA            |30    |
# |null|10   |584   |UA            |29    |
# |null|10   |691   |UA            |29    |
# |1987|null |733   |UA            |29    |
# |null|null |965   |UA            |1     |
# |null|10   |1066  |UA            |58    |
# |null|10   |1105  |UA            |60    |
# |null|null |1136  |UA            |30    |
# |1987|null |1203  |UA            |31    |
# |null|null |1221  |UA            |31    |
# |null|null |1233  |UA            |87    |
# |null|10   |1273  |UA            |29    |
# |null|null |1441  |UA            |82    |
# |null|null |1734  |UA            |1     |
# |null|10   |74    |WN            |22    |
# |1987|null |190   |WN            |30    |
# |null|10   |442   |WN            |87    |
# |null|null |760   |WN            |99    |
# |null|10   |780   |WN            |61    |
# |null|null |782   |WN            |118   |
# |null|null |884   |WN            |90    |
# |1987|10   |685   |AA            |151   |
# |1987|10   |2178  |AA            |60    |
# |1987|10   |3     |US            |92    |
# |1987|10   |209   |US            |25    |
# |1987|10   |224   |US            |62    |
# |1987|10   |255   |US            |29    |
# |1987|10   |411   |US            |31    |
# |1987|10   |579   |US            |31    |
# |1987|10   |432   |CO            |55    |
# |1987|10   |454   |CO            |24    |
# |1987|10   |522   |CO            |17    |
# |1987|10   |628   |CO            |20    |
# |1987|10   |759   |CO            |61    |
# |1987|10   |30    |null          |364   |
# |1987|10   |31    |null          |415   |
# |null|10   |68    |AA            |61    |
# |1987|null |86    |null          |426   |
# |1987|null |107   |null          |441   |
# |null|10   |150   |null          |369   |
# |null|null |168   |null          |276   |
# |null|null |187   |AA            |91    |
# |1987|null |194   |AA            |52    |
# |null|null |196   |AA            |90    |
# |1987|null |208   |AA            |89    |
# |null|null |208   |AA            |89    |
# |1987|null |284   |AA            |58    |
# |null|null |300   |null          |471   |
# |1987|null |310   |AA            |90    |
# |1987|10   |319   |null          |460   |
# |1987|10   |331   |null          |281   |
# |null|null |338   |AA            |59    |
# |1987|10   |361   |null          |390   |
# |null|10   |372   |AA            |28    |
# |1987|null |394   |AA            |59    |
# |null|null |405   |AA            |61    |
# |1987|10   |407   |null          |351   |
# |null|10   |421   |null          |334   |
# |1987|10   |427   |null          |531   |
# |1987|null |431   |null          |377   |
# |null|10   |432   |AA            |55    |
# |null|null |503   |AA            |61    |
# |null|null |522   |null          |301   |
# |null|10   |551   |null          |413   |
# |null|10   |624   |null          |261   |
# |null|10   |625   |AA            |91    |
# |null|10   |856   |AA            |61    |
# |1987|null |952   |null          |318   |
# |null|null |957   |AA            |62    |
# |1987|null |1016  |AA            |61    |
# |1987|null |1026  |AA            |61    |
# |null|10   |1037  |AA            |62    |
# |null|10   |1041  |AA            |60    |
# |1987|null |1045  |null          |120   |
# |1987|null |1055  |AA            |60    |
# |null|null |2009  |null          |86    |
# |null|10   |2064  |null          |27    |
# |1987|10   |2245  |null          |27    |
# |null|10   |2416  |null          |31    |
# |null|null |2543  |AA            |61    |
# |1987|null |53    |US            |92    |
# |1987|10   |104   |null          |426   |
# |1987|null |307   |US            |90    |
# |1987|null |384   |null          |278   |
# |null|10   |498   |US            |31    |
# |null|10   |503   |US            |82    |
# |null|10   |755   |null          |452   |
# |null|10   |897   |US            |5     |
# |1987|null |951   |US            |8     |
# |1987|null |962   |US            |8     |
# |null|null |973   |US            |5     |
# |null|10   |976   |US            |3     |
# |null|10   |748   |null          |487   |
# |null|10   |24    |CO            |30    |
# |null|10   |254   |CO            |57    |
# |null|null |281   |CO            |24    |
# |null|null |454   |CO            |24    |
# |null|10   |567   |CO            |89    |
# |null|null |593   |CO            |31    |
# |1987|null |660   |CO            |24    |
# |1987|10   |1047  |CO            |57    |
# |1987|10   |1758  |CO            |121   |
# |1987|10   |709   |DL            |30    |
# |1987|10   |912   |DL            |31    |
# |1987|10   |957   |DL            |61    |
# |1987|10   |14    |EA            |12    |
# |1987|10   |121   |EA            |52    |
# |1987|10   |515   |EA            |16    |
# |1987|10   |1021  |EA            |31    |
# |null|10   |776   |CO            |27    |
# |null|null |797   |CO            |28    |
# |null|null |823   |CO            |50    |
# |null|null |928   |CO            |62    |
# |null|10   |1099  |CO            |29    |
# |null|10   |1135  |null          |116   |
# |1987|null |1180  |CO            |54    |
# |null|10   |1256  |CO            |27    |
# |null|10   |1293  |null          |90    |
# |1987|null |1625  |CO            |86    |
# |null|10   |1751  |CO            |87    |
# |null|null |1754  |null          |70    |
# |1987|null |1796  |null          |111   |
# |null|null |3001  |CO            |31    |
# |null|10   |3009  |null          |31    |
# |null|null |294   |DL            |31    |
# |null|10   |351   |DL            |91    |
# |null|null |357   |DL            |90    |
# |null|null |442   |DL            |30    |
# |null|null |518   |DL            |31    |
# |null|10   |531   |DL            |8     |
# |null|10   |544   |DL            |30    |
# |null|10   |552   |DL            |5     |
# |null|10   |563   |DL            |56    |
# |1987|null |587   |DL            |62    |
# |1987|null |684   |DL            |62    |
# |null|10   |906   |DL            |29    |
# |null|10   |910   |DL            |59    |
# |1987|10   |947   |null          |182   |
# |1987|10   |964   |null          |202   |
# |1987|null |1007  |DL            |62    |
# |1987|10   |1437  |null          |50    |
# |1987|null |1445  |null          |88    |
# |1987|null |1502  |null          |140   |
# |null|10   |1543  |null          |85    |
# |1987|null |1576  |DL            |89    |
# |1987|null |1642  |DL            |61    |
# |null|10   |1696  |null          |106   |
# |null|10   |1703  |null          |91    |
# |1987|null |1783  |null          |54    |
# |null|null |1863  |DL            |30    |
# |1987|null |1904  |null          |74    |
# |1987|10   |1917  |null          |58    |
# |null|10   |92    |EA            |73    |
# |null|10   |151   |EA            |30    |
# |null|null |256   |EA            |22    |
# |1987|null |262   |EA            |63    |
# |1987|null |485   |EA            |27    |
# |1987|null |530   |EA            |117   |
# |null|10   |563   |EA            |61    |
# |null|null |622   |EA            |52    |
# |null|10   |649   |EA            |52    |
# |null|10   |658   |EA            |27    |
# |null|null |772   |EA            |60    |
# |1987|null |816   |EA            |58    |
# |null|10   |919   |EA            |28    |
# |1987|null |986   |EA            |9     |
# |1987|10   |53    |NW            |55    |
# |1987|10   |505   |NW            |61    |
# |1987|10   |1481  |NW            |31    |
# |1987|10   |749   |PI            |26    |
# |null|null |1617  |EA            |28    |
# |1987|null |1840  |EA            |9     |
# |null|10   |1843  |EA            |4     |
# |null|null |null  |HP            |15026 |
# |null|10   |526   |HP            |62    |
# |1987|null |1264  |HP            |27    |
# |1987|null |38    |NW            |29    |
# |null|null |195   |NW            |60    |
# |null|null |252   |NW            |29    |
# |null|10   |278   |NW            |54    |
# |null|null |418   |NW            |30    |
# |null|10   |453   |NW            |31    |
# |null|10   |490   |NW            |48    |
# |null|null |499   |NW            |49    |
# |null|10   |580   |NW            |31    |
# |null|null |583   |NW            |24    |
# |null|null |596   |NW            |31    |
# |null|10   |628   |NW            |117   |
# |1987|null |887   |NW            |61    |
# |null|null |1183  |NW            |56    |
# |null|null |246   |PA (1)        |31    |
# |null|null |539   |PA (1)        |31    |
# |null|null |31    |PI            |60    |
# |null|10   |245   |PI            |51    |
# |1987|null |430   |PI            |54    |
# |1987|null |461   |PI            |52    |
# |1987|null |657   |PI            |93    |
# |null|10   |708   |PI            |31    |
# |1987|null |763   |PI            |58    |
# |1987|null |769   |PI            |9     |
# |null|10   |845   |PI            |114   |
# |null|10   |1408  |PS            |25    |
# |1987|10   |1463  |null          |30    |
# |1987|null |1490  |PS            |60    |
# |null|null |1554  |PS            |25    |
# |null|null |1560  |PS            |56    |
# |1987|10   |1594  |null          |10    |
# |1987|10   |1739  |null          |34    |
# |null|null |1801  |PS            |25    |
# |null|10   |1806  |null          |19    |
# |null|null |1828  |PS            |50    |
# |null|10   |1835  |null          |45    |
# |1987|null |1867  |PS            |5     |
# |null|null |1870  |PS            |48    |
# |null|10   |1879  |PS            |27    |
# |null|null |1910  |PS            |31    |
# |null|10   |75    |TW            |55    |
# |1987|null |87    |TW            |62    |
# |null|null |114   |TW            |57    |
# |1987|10   |543   |TW            |58    |
# |1987|10   |596   |TW            |60    |
# |1987|10   |2     |UA            |29    |
# |1987|10   |302   |UA            |1     |
# |1987|10   |391   |UA            |60    |
# |1987|10   |403   |UA            |123   |
# |1987|10   |570   |UA            |92    |
# |1987|10   |1043  |UA            |61    |
# |1987|10   |1163  |UA            |31    |
# |1987|null |277   |TW            |26    |
# |null|null |357   |TW            |6     |
# |null|null |410   |TW            |84    |
# |1987|null |70    |UA            |92    |
# |1987|null |108   |UA            |54    |
# |null|10   |139   |UA            |60    |
# |1987|null |217   |UA            |61    |
# |null|null |220   |UA            |59    |
# |null|null |229   |UA            |58    |
# |1987|null |259   |UA            |25    |
# |null|null |548   |UA            |88    |
# |null|null |563   |UA            |57    |
# |null|null |584   |UA            |29    |
# |1987|null |685   |UA            |59    |
# |null|10   |704   |UA            |120   |
# |null|null |751   |UA            |59    |
# |null|10   |851   |UA            |1     |
# |1987|null |901   |UA            |54    |
# |1987|null |956   |UA            |62    |
# |null|null |958   |UA            |31    |
# |null|10   |1052  |UA            |4     |
# |null|10   |1092  |UA            |30    |
# |null|10   |1124  |UA            |26    |
# |1987|null |1144  |null          |90    |
# |1987|10   |1154  |null          |59    |
# |null|null |58    |WN            |55    |
# |1987|null |731   |WN            |22    |
# |null|null |869   |WN            |101   |
# |1987|10   |157   |AA            |57    |
# |1987|10   |190   |AA            |56    |
# |1987|10   |418   |AA            |56    |
# |1987|10   |519   |AA            |59    |
# |1987|10   |443   |US            |24    |
# |1987|10   |700   |CO            |56    |
# |null|null |20    |AA            |22    |
# |1987|10   |52    |null          |503   |
# |null|10   |76    |null          |329   |
# |null|10   |78    |AA            |26    |
# |1987|null |108   |AA            |58    |
# |1987|10   |110   |null          |440   |
# |null|10   |114   |null          |466   |
# |1987|10   |216   |null          |352   |
# |null|10   |224   |null          |556   |
# |null|null |247   |null          |398   |
# |null|null |256   |AA            |60    |
# |null|null |277   |AA            |57    |
# |null|10   |282   |null          |308   |
# |1987|10   |335   |null          |373   |
# |null|null |339   |AA            |88    |
# |1987|null |454   |AA            |57    |
# |null|10   |459   |AA            |59    |
# |1987|null |521   |AA            |60    |
# |null|10   |537   |null          |640   |
# |1987|10   |559   |null          |504   |
# |1987|null |591   |AA            |61    |
# |null|10   |678   |null          |378   |
# |1987|null |830   |AA            |93    |
# |1987|10   |832   |null          |392   |
# |null|null |841   |null          |294   |
# |null|null |850   |null          |380   |
# |1987|null |1088  |AA            |62    |
# |1987|null |2025  |null          |5     |
# |1987|null |2154  |null          |61    |
# |null|10   |2344  |null          |26    |
# |null|10   |2357  |null          |29    |
# |1987|null |2402  |null          |25    |
# |1987|null |2688  |AA            |62    |
# |null|10   |68    |US            |57    |
# |1987|null |75    |US            |61    |
# |null|10   |177   |US            |30    |
# |1987|null |342   |US            |61    |
# |1987|null |473   |US            |61    |
# |1987|null |533   |US            |57    |
# |1987|null |686   |null          |235   |
# |1987|null |745   |US            |1     |
# |1987|null |950   |US            |5     |
# |null|10   |70    |AS            |26    |
# |1987|null |92    |AS            |78    |
# |null|null |118   |AS            |40    |
# |null|null |119   |AS            |20    |
# |null|null |201   |AS            |56    |
# |null|10   |733   |null          |431   |
# |null|null |85    |CO            |56    |
# |1987|null |264   |CO            |60    |
# |1987|null |427   |CO            |58    |
# |null|null |480   |CO            |56    |
# |null|null |490   |CO            |31    |
# |null|null |538   |CO            |61    |
# |null|10   |669   |CO            |53    |
# |1987|null |688   |CO            |61    |
# |null|null |701   |CO            |29    |
# |1987|null |730   |CO            |57    |
# |1987|10   |379   |DL            |87    |
# |1987|10   |498   |DL            |29    |
# |1987|10   |672   |DL            |30    |
# |1987|10   |729   |DL            |31    |
# |1987|10   |908   |DL            |52    |
# |1987|10   |1073  |DL            |29    |
# |1987|10   |1579  |DL            |60    |
# |1987|10   |1782  |DL            |30    |
# |1987|10   |12    |EA            |26    |
# |1987|10   |20    |EA            |25    |
# |1987|10   |316   |EA            |28    |
# |1987|10   |349   |EA            |83    |
# |1987|10   |511   |EA            |57    |
# |1987|10   |585   |EA            |62    |
# |1987|10   |714   |EA            |60    |
# |1987|10   |735   |EA            |89    |
# |1987|10   |854   |EA            |26    |
# |null|10   |760   |CO            |30    |
# |null|null |1012  |null          |64    |
# |null|null |1092  |CO            |60    |
# |null|10   |1239  |null          |83    |
# |null|10   |1684  |CO            |57    |
# |null|null |1712  |null          |117   |
# |null|10   |1751  |null          |118   |
# |1987|10   |1758  |null          |143   |
# |null|null |3003  |CO            |31    |
# |null|10   |3006  |null          |31    |
# |null|10   |3008  |CO            |31    |
# |null|null |355   |DL            |30    |
# |1987|null |377   |DL            |91    |
# |null|10   |436   |DL            |31    |
# |null|10   |554   |DL            |31    |
# |null|null |862   |DL            |57    |
# |null|null |933   |DL            |61    |
# |1987|null |938   |DL            |27    |
# |1987|null |1422  |null          |206   |
# |null|10   |1436  |DL            |62    |
# |null|10   |1505  |DL            |60    |
# |1987|10   |1556  |null          |31    |
# |1987|null |1651  |DL            |88    |
# |null|10   |1658  |DL            |155   |
# |1987|null |1723  |null          |134   |
# |1987|null |1724  |DL            |61    |
# |null|null |1927  |DL            |26    |
# |null|null |28    |EA            |27    |
# |null|null |69    |EA            |50    |
# |null|null |127   |EA            |29    |
# |null|10   |143   |EA            |60    |
# |1987|null |282   |EA            |29    |
# |null|null |282   |EA            |29    |
# |null|10   |339   |EA            |18    |
# |null|10   |500   |EA            |31    |
# |1987|null |744   |EA            |23    |
# |null|10   |767   |EA            |60    |
# |1987|null |887   |EA            |60    |
# |1987|10   |1461  |EA            |31    |
# |1987|10   |35    |HP            |54    |
# |1987|10   |1202  |HP            |30    |
# |1987|10   |46    |NW            |26    |
# |1987|10   |453   |NW            |31    |
# |1987|10   |834   |NW            |29    |
# |1987|10   |264   |PA (1)        |31    |
# |1987|10   |523   |PA (1)        |27    |
# |1987|10   |526   |PA (1)        |31    |
# |1987|10   |224   |PI            |31    |
# |1987|10   |455   |PI            |93    |
# |1987|10   |509   |PI            |62    |
# |1987|10   |1517  |PS            |53    |
# |1987|10   |1843  |PS            |72    |
# |null|10   |1511  |EA            |31    |
# |1987|null |1631  |EA            |30    |
# |null|10   |1865  |null          |26    |
# |1987|null |1946  |EA            |5     |
# |null|10   |1953  |null          |9     |
# |null|null |4504  |EA            |1     |
# |null|10   |4938  |null          |11    |
# |null|null |1026  |HP            |59    |
# |1987|null |1205  |HP            |30    |
# |null|10   |1235  |HP            |22    |
# |null|10   |1259  |null          |119   |
# |null|null |85    |NW            |60    |
# |1987|null |228   |NW            |56    |
# |1987|null |239   |NW            |25    |
# |1987|null |263   |NW            |49    |
# |null|null |290   |NW            |60    |
# |null|10   |418   |NW            |30    |
# |null|10   |570   |NW            |31    |
# |null|10   |804   |NW            |56    |
# |null|10   |958   |NW            |61    |
# |null|10   |1020  |NW            |30    |
# |null|null |1054  |NW            |79    |
# |null|10   |1080  |NW            |58    |
# |null|null |1393  |NW            |51    |
# |1987|null |1424  |NW            |55    |
# |null|null |1480  |NW            |55    |
# |null|null |230   |PA (1)        |26    |
# |null|null |588   |PA (1)        |60    |
# |null|null |223   |PI            |60    |
# |null|10   |228   |PI            |2     |
# |null|10   |321   |PI            |62    |
# |1987|null |352   |PI            |26    |
# |1987|null |385   |PI            |62    |
# |1987|null |547   |PI            |61    |
# |null|null |711   |PI            |27    |
# |1987|null |830   |PI            |26    |
# |1987|null |848   |PI            |92    |
# |null|null |870   |PI            |60    |
# |null|10   |874   |PI            |62    |
# |null|10   |959   |PI            |62    |
# |1987|null |1442  |PS            |62    |
# |null|10   |1446  |PS            |25    |
# |1987|10   |1525  |null          |32    |
# |1987|null |1603  |PS            |29    |
# |null|null |1672  |PS            |29    |
# |null|null |1762  |PS            |76    |
# |1987|null |1781  |PS            |22    |
# |null|10   |1790  |PS            |24    |
# |1987|null |1822  |PS            |36    |
# |null|10   |1822  |PS            |36    |
# |null|10   |1836  |null          |1     |
# |null|10   |1886  |PS            |60    |
# |null|10   |1909  |PS            |20    |
# |null|10   |1991  |null          |5     |
# |null|null |29    |TW            |60    |
# |1987|10   |68    |UA            |30    |
# |1987|10   |591   |UA            |61    |
# |1987|10   |1709  |UA            |6     |
# |1987|10   |997   |WN            |72    |
# |null|10   |161   |TW            |84    |
# |null|10   |199   |TW            |58    |
# |null|null |199   |TW            |58    |
# |null|10   |226   |TW            |51    |
# |null|null |231   |TW            |7     |
# |1987|null |250   |TW            |63    |
# |1987|null |416   |TW            |60    |
# |null|10   |507   |TW            |61    |
# |null|null |731   |TW            |59    |
# |1987|null |840   |TW            |28    |
# |null|null |862   |TW            |7     |
# |1987|null |45    |UA            |31    |
# |null|10   |56    |UA            |58    |
# |null|10   |79    |UA            |30    |
# |null|10   |110   |UA            |28    |
# |1987|null |287   |UA            |28    |
# |null|10   |316   |UA            |27    |
# |null|10   |332   |UA            |30    |
# |null|null |403   |UA            |123   |
# |null|null |405   |UA            |30    |
# |null|null |570   |UA            |92    |
# |null|null |818   |UA            |11    |
# |null|null |851   |UA            |1     |
# |null|null |1040  |UA            |32    |
# |null|null |1066  |UA            |58    |
# |1987|null |1210  |UA            |1     |
# |null|null |1262  |UA            |61    |
# |null|null |1266  |UA            |1     |
# |1987|null |1277  |UA            |2     |
# |null|10   |1423  |UA            |90    |
# |null|null |1589  |UA            |1     |
# |null|10   |1701  |UA            |3     |
# |null|null |1771  |UA            |1     |
# |null|null |87    |WN            |44    |
# |null|null |178   |WN            |4     |
# |null|10   |189   |WN            |57    |
# |null|null |338   |WN            |40    |
# |1987|null |362   |WN            |4     |
# |1987|null |945   |WN            |26    |
# |null|null |994   |WN            |53    |
# |1987|10   |491   |AA            |39    |
# |1987|10   |297   |US            |58    |
# |1987|10   |404   |US            |57    |
# |1987|10   |160   |AS            |28    |
# |1987|10   |174   |AS            |100   |
# |1987|10   |103   |CO            |59    |
# |1987|10   |126   |CO            |58    |
# |1987|10   |440   |CO            |31    |
# |1987|10   |475   |CO            |23    |
# |1987|10   |527   |CO            |48    |
# |1987|10   |538   |CO            |61    |
# |1987|10   |null  |null          |448620|
# |null|10   |20    |null          |445   |
# |null|10   |27    |AA            |24    |
# |null|null |27    |AA            |24    |
# |1987|null |82    |null          |385   |
# |1987|null |155   |null          |392   |
# |null|null |158   |AA            |58    |
# |1987|null |256   |AA            |60    |
# |1987|10   |338   |null          |378   |
# |1987|10   |345   |null          |546   |
# |null|10   |353   |null          |527   |
# |1987|null |391   |AA            |62    |
# |null|10   |407   |null          |351   |
# |null|10   |426   |null          |482   |
# |null|10   |453   |null          |535   |
# |null|null |459   |null          |403   |
# |1987|null |508   |AA            |87    |
# |null|null |513   |AA            |61    |
# |null|null |539   |null          |597   |
# |1987|10   |589   |null          |393   |
# |1987|10   |598   |null          |449   |
# |null|10   |602   |AA            |58    |
# |null|null |811   |AA            |58    |
# |1987|10   |813   |null          |150   |
# |null|10   |846   |null          |377   |
# |1987|null |876   |AA            |90    |
# |null|null |916   |AA            |60    |
# |null|10   |923   |null          |310   |
# |null|10   |933   |AA            |60    |
# |1987|null |1025  |AA            |91    |
# |1987|10   |1086  |null          |174   |
# |1987|null |2011  |AA            |22    |
# |1987|10   |2052  |null          |91    |
# |null|null |2112  |null          |25    |
# |1987|null |2128  |AA            |30    |
# |null|null |2144  |null          |62    |
# |1987|null |2273  |AA            |26    |
# |1987|null |2342  |AA            |29    |
# |null|10   |2425  |AA            |29    |
# |null|null |9     |US            |61    |
# +----+-----+------+--------------+------+
# only showing top 1000 rows

# %%
# While The cube function “takes a list of columns and applies 
# aggregate expressions to all possible combinations of the grouping columns”. And, order of
# the arguments listed inside the cube does not matter
# rollup, on the other hand, is a specific subset of 'cube' that "computes hierarchical subtotals" 
# from left to right

# %%
dfRollup1=df.rollup(df.YEAR, df.MONTH,df.FL_NUM, df.UNIQUE_CARRIER).count().show(1000,False)
# Out:
# +----+-----+------+--------------+------+
# |YEAR|MONTH|FL_NUM|UNIQUE_CARRIER|count |
# +----+-----+------+--------------+------+
# |1987|10   |195   |AA            |62    |
# |1987|10   |226   |AA            |57    |
# |1987|10   |265   |AA            |92    |
# |1987|10   |303   |AA            |62    |
# |1987|10   |530   |AA            |61    |
# |1987|10   |595   |AA            |30    |
# |1987|10   |973   |AA            |93    |
# |1987|10   |1004  |AA            |60    |
# |1987|10   |1062  |AA            |59    |
# |1987|10   |2183  |AA            |89    |
# |1987|10   |2404  |AA            |31    |
# |1987|10   |174   |US            |60    |
# |1987|10   |279   |US            |86    |
# |1987|10   |395   |AS            |59    |
# |1987|10   |313   |CO            |31    |
# |1987|10   |573   |CO            |54    |
# |1987|10   |675   |null          |423   |
# |1987|10   |803   |null          |466   |
# |1987|10   |1093  |null          |138   |
# |1987|10   |2144  |null          |62    |
# |1987|10   |2273  |null          |26    |
# |1987|10   |763   |CO            |28    |
# |1987|10   |1083  |CO            |61    |
# |1987|10   |1291  |CO            |5     |
# |1987|10   |1725  |CO            |58    |
# |1987|10   |52    |DL            |25    |
# |1987|10   |192   |DL            |31    |
# |1987|10   |298   |DL            |60    |
# |1987|10   |520   |DL            |31    |
# |1987|10   |523   |DL            |62    |
# |1987|10   |671   |DL            |93    |
# |1987|10   |1543  |DL            |62    |
# |1987|10   |85    |EA            |76    |
# |1987|10   |466   |EA            |58    |
# |1987|10   |503   |EA            |28    |
# |1987|10   |578   |EA            |57    |
# |1987|10   |602   |EA            |83    |
# |1987|10   |656   |EA            |25    |
# |1987|10   |682   |EA            |55    |
# |1987|10   |776   |EA            |57    |
# |1987|10   |1103  |null          |193   |
# |1987|10   |1180  |null          |111   |
# |1987|10   |829   |null          |357   |
# |1987|10   |1564  |null          |130   |
# |1987|10   |1667  |null          |104   |
# |1987|10   |1988  |EA            |5     |
# |1987|10   |17    |HP            |62    |
# |1987|10   |426   |HP            |58    |
# |1987|10   |1233  |HP            |17    |
# |1987|10   |1259  |HP            |31    |
# |1987|10   |132   |NW            |25    |
# |1987|10   |146   |NW            |58    |
# |1987|10   |1146  |NW            |84    |
# |1987|10   |206   |PA (1)        |53    |
# |1987|10   |539   |PA (1)        |31    |
# |1987|10   |582   |PA (1)        |27    |
# |1987|10   |377   |PI            |61    |
# |1987|10   |390   |PI            |62    |
# |1987|10   |404   |PI            |62    |
# |1987|10   |832   |PI            |62    |
# |1987|10   |949   |PI            |13    |
# |1987|10   |1849  |PS            |1     |
# |1987|10   |1281  |null          |140   |
# |1987|10   |1771  |null          |52    |
# |1987|10   |345   |TW            |86    |
# |1987|10   |400   |TW            |87    |
# |1987|10   |488   |TW            |59    |
# |1987|10   |614   |TW            |61    |
# |1987|10   |118   |UA            |87    |
# |1987|10   |484   |UA            |61    |
# |1987|10   |704   |UA            |120   |
# |1987|10   |753   |UA            |29    |
# |1987|10   |87    |WN            |44    |
# |1987|10   |164   |WN            |4     |
# |1987|10   |412   |WN            |44    |
# |1987|10   |995   |WN            |51    |
# |1987|10   |207   |AA            |88    |
# |1987|10   |643   |AA            |30    |
# |1987|10   |906   |AA            |30    |
# |1987|10   |1069  |AA            |61    |
# |1987|10   |66    |US            |61    |
# |1987|10   |162   |US            |49    |
# |1987|10   |611   |US            |62    |
# |1987|10   |105   |AS            |26    |
# |1987|10   |316   |CO            |31    |
# |1987|10   |461   |CO            |55    |
# |1987|10   |174   |null          |385   |
# |1987|10   |276   |null          |464   |
# |1987|10   |389   |null          |198   |
# |1987|10   |2044  |null          |26    |
# |1987|10   |874   |CO            |61    |
# |1987|10   |1110  |CO            |29    |
# |1987|10   |1681  |CO            |26    |
# |1987|10   |519   |DL            |31    |
# |1987|10   |933   |DL            |61    |
# |1987|10   |1092  |DL            |60    |
# |1987|10   |1946  |DL            |31    |
# |1987|10   |123   |EA            |55    |
# |1987|10   |155   |EA            |61    |
# |1987|10   |627   |EA            |23    |
# |1987|10   |916   |EA            |30    |
# |1987|10   |1638  |null          |148   |
# |1987|10   |1756  |null          |81    |
# |1987|10   |1826  |null          |59    |
# |1987|10   |1866  |null          |53    |
# |1987|10   |1919  |null          |53    |
# |1987|10   |1206  |HP            |27    |
# |1987|10   |406   |NW            |29    |
# |1987|10   |433   |NW            |60    |
# |1987|10   |479   |NW            |73    |
# |1987|10   |545   |NW            |28    |
# |1987|10   |104   |PI            |57    |
# |1987|10   |294   |PI            |4     |
# |1987|10   |768   |PI            |30    |
# |1987|10   |796   |PI            |31    |
# |1987|10   |1637  |PS            |28    |
# |1987|10   |77    |TW            |58    |
# |1987|10   |732   |TW            |50    |
# |1987|10   |132   |UA            |25    |
# |1987|10   |432   |UA            |25    |
# |1987|10   |565   |UA            |26    |
# |1987|10   |569   |UA            |28    |
# |1987|10   |717   |UA            |121   |
# |1987|10   |769   |UA            |32    |
# |1987|10   |1476  |UA            |114   |
# |1987|10   |1553  |UA            |2     |
# |1987|10   |963   |WN            |154   |
# |1987|10   |685   |AA            |151   |
# |1987|10   |2178  |AA            |60    |
# |1987|10   |3     |US            |92    |
# |1987|10   |209   |US            |25    |
# |1987|10   |224   |US            |62    |
# |1987|10   |255   |US            |29    |
# |1987|10   |411   |US            |31    |
# |1987|10   |579   |US            |31    |
# |1987|10   |432   |CO            |55    |
# |1987|10   |454   |CO            |24    |
# |1987|10   |522   |CO            |17    |
# |1987|10   |628   |CO            |20    |
# |1987|10   |759   |CO            |61    |
# |1987|10   |30    |null          |364   |
# |1987|10   |31    |null          |415   |
# |1987|10   |319   |null          |460   |
# |1987|10   |331   |null          |281   |
# |1987|10   |361   |null          |390   |
# |1987|10   |407   |null          |351   |
# |1987|10   |427   |null          |531   |
# |1987|10   |2245  |null          |27    |
# |1987|10   |104   |null          |426   |
# |1987|10   |1047  |CO            |57    |
# |1987|10   |1758  |CO            |121   |
# |1987|10   |709   |DL            |30    |
# |1987|10   |912   |DL            |31    |
# |1987|10   |957   |DL            |61    |
# |1987|10   |14    |EA            |12    |
# |1987|10   |121   |EA            |52    |
# |1987|10   |515   |EA            |16    |
# |1987|10   |1021  |EA            |31    |
# |1987|10   |947   |null          |182   |
# |1987|10   |964   |null          |202   |
# |1987|10   |1437  |null          |50    |
# |1987|10   |1917  |null          |58    |
# |1987|10   |53    |NW            |55    |
# |1987|10   |505   |NW            |61    |
# |1987|10   |1481  |NW            |31    |
# |1987|10   |749   |PI            |26    |
# |1987|10   |1463  |null          |30    |
# |1987|10   |1594  |null          |10    |
# |1987|10   |1739  |null          |34    |
# |1987|10   |543   |TW            |58    |
# |1987|10   |596   |TW            |60    |
# |1987|10   |2     |UA            |29    |
# |1987|10   |302   |UA            |1     |
# |1987|10   |391   |UA            |60    |
# |1987|10   |403   |UA            |123   |
# |1987|10   |570   |UA            |92    |
# |1987|10   |1043  |UA            |61    |
# |1987|10   |1163  |UA            |31    |
# |1987|10   |1154  |null          |59    |
# |1987|10   |157   |AA            |57    |
# |1987|10   |190   |AA            |56    |
# |1987|10   |418   |AA            |56    |
# |1987|10   |519   |AA            |59    |
# |1987|10   |443   |US            |24    |
# |1987|10   |700   |CO            |56    |
# |1987|10   |52    |null          |503   |
# |1987|10   |110   |null          |440   |
# |1987|10   |216   |null          |352   |
# |1987|10   |335   |null          |373   |
# |1987|10   |559   |null          |504   |
# |1987|10   |832   |null          |392   |
# |1987|10   |379   |DL            |87    |
# |1987|10   |498   |DL            |29    |
# |1987|10   |672   |DL            |30    |
# |1987|10   |729   |DL            |31    |
# |1987|10   |908   |DL            |52    |
# |1987|10   |1073  |DL            |29    |
# |1987|10   |1579  |DL            |60    |
# |1987|10   |1782  |DL            |30    |
# |1987|10   |12    |EA            |26    |
# |1987|10   |20    |EA            |25    |
# |1987|10   |316   |EA            |28    |
# |1987|10   |349   |EA            |83    |
# |1987|10   |511   |EA            |57    |
# |1987|10   |585   |EA            |62    |
# |1987|10   |714   |EA            |60    |
# |1987|10   |735   |EA            |89    |
# |1987|10   |854   |EA            |26    |
# |1987|10   |1758  |null          |143   |
# |1987|10   |1556  |null          |31    |
# |1987|10   |1461  |EA            |31    |
# |1987|10   |35    |HP            |54    |
# |1987|10   |1202  |HP            |30    |
# |1987|10   |46    |NW            |26    |
# |1987|10   |453   |NW            |31    |
# |1987|10   |834   |NW            |29    |
# |1987|10   |264   |PA (1)        |31    |
# |1987|10   |523   |PA (1)        |27    |
# |1987|10   |526   |PA (1)        |31    |
# |1987|10   |224   |PI            |31    |
# |1987|10   |455   |PI            |93    |
# |1987|10   |509   |PI            |62    |
# |1987|10   |1517  |PS            |53    |
# |1987|10   |1843  |PS            |72    |
# |1987|10   |1525  |null          |32    |
# |1987|10   |68    |UA            |30    |
# |1987|10   |591   |UA            |61    |
# |1987|10   |1709  |UA            |6     |
# |1987|10   |997   |WN            |72    |
# |1987|10   |491   |AA            |39    |
# |1987|10   |297   |US            |58    |
# |1987|10   |404   |US            |57    |
# |1987|10   |160   |AS            |28    |
# |1987|10   |174   |AS            |100   |
# |1987|10   |103   |CO            |59    |
# |1987|10   |126   |CO            |58    |
# |1987|10   |440   |CO            |31    |
# |1987|10   |475   |CO            |23    |
# |1987|10   |527   |CO            |48    |
# |1987|10   |538   |CO            |61    |
# |1987|10   |null  |null          |448620|
# |1987|10   |338   |null          |378   |
# |1987|10   |345   |null          |546   |
# |1987|10   |589   |null          |393   |
# |1987|10   |598   |null          |449   |
# |1987|10   |813   |null          |150   |
# |1987|10   |1086  |null          |174   |
# |1987|10   |2052  |null          |91    |
# |1987|10   |54    |null          |341   |
# |1987|10   |962   |null          |277   |
# |1987|10   |1153  |CO            |29    |
# |1987|10   |1609  |CO            |56    |
# |1987|10   |3012  |CO            |31    |
# |1987|10   |225   |DL            |61    |
# |1987|10   |244   |DL            |31    |
# |1987|10   |245   |DL            |59    |
# |1987|10   |412   |DL            |86    |
# |1987|10   |522   |DL            |60    |
# |1987|10   |548   |DL            |90    |
# |1987|10   |635   |DL            |31    |
# |1987|10   |637   |DL            |92    |
# |1987|10   |1588  |DL            |12    |
# |1987|10   |1822  |DL            |62    |
# |1987|10   |22    |EA            |7     |
# |1987|10   |122   |EA            |61    |
# |1987|10   |145   |EA            |57    |
# |1987|10   |394   |EA            |90    |
# |1987|10   |521   |EA            |31    |
# |1987|10   |786   |null          |326   |
# |1987|10   |1611  |null          |87    |
# |1987|10   |1783  |null          |54    |
# |1987|10   |1926  |null          |83    |
# |1987|10   |1218  |HP            |29    |
# |1987|10   |306   |NW            |29    |
# |1987|10   |1020  |NW            |30    |
# |1987|10   |220   |PA (1)        |21    |
# |1987|10   |364   |PA (1)        |28    |
# |1987|10   |395   |PA (1)        |29    |
# |1987|10   |461   |PI            |52    |
# |1987|10   |555   |PI            |62    |
# |1987|10   |717   |PI            |26    |
# |1987|10   |1546  |PS            |55    |
# |1987|10   |1672  |PS            |29    |
# |1987|10   |24    |TW            |94    |
# |1987|10   |65    |TW            |63    |
# |1987|10   |1288  |null          |59    |
# |1987|10   |103   |UA            |29    |
# |1987|10   |453   |UA            |60    |
# |1987|10   |669   |UA            |59    |
# |1987|10   |1105  |UA            |60    |
# |1987|10   |318   |AA            |31    |
# |1987|10   |447   |AA            |62    |
# |1987|10   |835   |AA            |150   |
# |1987|10   |429   |US            |50    |
# |1987|10   |477   |US            |60    |
# |1987|10   |622   |US            |30    |
# |1987|10   |67    |AS            |161   |
# |1987|10   |557   |CO            |26    |
# |1987|10   |635   |CO            |21    |
# |1987|10   |698   |CO            |28    |
# |1987|10   |755   |CO            |60    |
# |1987|10   |66    |null          |662   |
# |1987|10   |234   |null          |481   |
# |1987|10   |393   |null          |413   |
# |1987|10   |423   |null          |378   |
# |1987|10   |687   |null          |372   |
# |1987|10   |844   |null          |292   |
# |1987|10   |2354  |null          |31    |
# |1987|10   |921   |null          |278   |
# |1987|10   |714   |null          |286   |
# |1987|10   |833   |CO            |29    |
# |1987|10   |865   |CO            |58    |
# |1987|10   |1116  |CO            |20    |
# |1987|10   |458   |DL            |30    |
# |1987|10   |467   |DL            |87    |
# |1987|10   |648   |DL            |90    |
# |1987|10   |706   |DL            |29    |
# |1987|10   |856   |DL            |28    |
# |1987|10   |1072  |DL            |62    |
# |1987|10   |1421  |DL            |60    |
# |1987|10   |1784  |DL            |30    |
# |1987|10   |1866  |DL            |30    |
# |1987|10   |1941  |DL            |29    |
# |1987|10   |310   |EA            |61    |
# |1987|10   |317   |EA            |58    |
# |1987|10   |461   |EA            |31    |
# |1987|10   |761   |EA            |30    |
# |1987|10   |1163  |null          |124   |
# |1987|10   |1775  |null          |60    |
# |1987|10   |424   |NW            |56    |
# |1987|10   |496   |NW            |46    |
# |1987|10   |83    |PI            |61    |
# |1987|10   |432   |PI            |92    |
# |1987|10   |946   |PI            |88    |
# |1987|10   |1590  |PS            |21    |
# |1987|10   |1679  |PS            |28    |
# |1987|10   |1265  |null          |27    |
# |1987|10   |267   |UA            |59    |
# |1987|10   |344   |UA            |56    |
# |1987|10   |437   |UA            |31    |
# |1987|10   |749   |UA            |63    |
# |1987|10   |980   |UA            |91    |
# |1987|10   |50    |WN            |166   |
# |1987|10   |70    |WN            |78    |
# |1987|10   |242   |WN            |31    |
# |1987|10   |774   |WN            |24    |
# |1987|10   |1208  |null          |31    |
# |1987|10   |293   |AA            |62    |
# |1987|10   |302   |AA            |61    |
# |1987|10   |543   |AA            |57    |
# |1987|10   |827   |AA            |61    |
# |1987|10   |1039  |AA            |61    |
# |1987|10   |103   |US            |62    |
# |1987|10   |318   |US            |58    |
# |1987|10   |319   |US            |55    |
# |1987|10   |51    |AS            |81    |
# |1987|10   |11    |CO            |1     |
# |1987|10   |308   |CO            |25    |
# |1987|10   |543   |CO            |51    |
# |1987|10   |572   |CO            |58    |
# |1987|10   |2     |null          |513   |
# |1987|10   |209   |null          |228   |
# |1987|10   |504   |null          |379   |
# |1987|10   |610   |null          |285   |
# |1987|10   |637   |null          |402   |
# |1987|10   |680   |null          |392   |
# |1987|10   |2140  |null          |24    |
# |1987|10   |785   |CO            |61    |
# |1987|10   |1103  |CO            |62    |
# |1987|10   |1198  |CO            |26    |
# |1987|10   |1206  |CO            |31    |
# |1987|10   |1623  |CO            |57    |
# |1987|10   |255   |DL            |30    |
# |1987|10   |748   |DL            |52    |
# |1987|10   |772   |DL            |29    |
# |1987|10   |826   |DL            |61    |
# |1987|10   |977   |DL            |8     |
# |1987|10   |1006  |DL            |61    |
# |1987|10   |1035  |DL            |30    |
# |1987|10   |1569  |DL            |30    |
# |1987|10   |1615  |DL            |30    |
# |1987|10   |1896  |DL            |60    |
# |1987|10   |833   |EA            |29    |
# |1987|10   |1270  |null          |193   |
# |1987|10   |207   |HP            |58    |
# |1987|10   |631   |HP            |58    |
# |1987|10   |1257  |HP            |27    |
# |1987|10   |1059  |NW            |59    |
# |1987|10   |501   |PA (1)        |26    |
# |1987|10   |568   |PA (1)        |62    |
# |1987|10   |357   |PI            |19    |
# |1987|10   |771   |PI            |31    |
# |1987|10   |772   |PI            |31    |
# |1987|10   |1588  |PS            |50    |
# |1987|10   |330   |UA            |61    |
# |1987|10   |528   |UA            |28    |
# |1987|10   |622   |UA            |61    |
# |1987|10   |737   |UA            |92    |
# |1987|10   |12    |WN            |60    |
# |1987|10   |57    |WN            |71    |
# |1987|10   |409   |WN            |50    |
# |1987|10   |884   |WN            |90    |
# |1987|10   |967   |WN            |47    |
# |1987|10   |125   |AA            |30    |
# |1987|10   |140   |AA            |62    |
# |1987|10   |198   |AA            |56    |
# |1987|10   |2702  |AA            |90    |
# |1987|10   |29    |US            |119   |
# |1987|10   |82    |US            |25    |
# |1987|10   |170   |US            |86    |
# |1987|10   |214   |US            |31    |
# |1987|10   |364   |US            |59    |
# |1987|10   |422   |US            |50    |
# |1987|10   |615   |US            |26    |
# |1987|10   |279   |CO            |28    |
# |1987|10   |408   |CO            |54    |
# |1987|10   |672   |CO            |56    |
# |1987|10   |686   |CO            |29    |
# |1987|10   |198   |null          |229   |
# |1987|10   |892   |null          |397   |
# |1987|10   |2057  |null          |29    |
# |1987|10   |2724  |null          |59    |
# |1987|10   |2735  |null          |60    |
# |1987|10   |1055  |CO            |61    |
# |1987|10   |283   |DL            |31    |
# |1987|10   |483   |DL            |62    |
# |1987|10   |764   |DL            |27    |
# |1987|10   |773   |DL            |60    |
# |1987|10   |1077  |DL            |24    |
# |1987|10   |1943  |DL            |57    |
# |1987|10   |139   |EA            |55    |
# |1987|10   |141   |EA            |52    |
# |1987|10   |749   |EA            |23    |
# |1987|10   |755   |EA            |57    |
# |1987|10   |1682  |null          |90    |
# |1987|10   |1688  |null          |31    |
# |1987|10   |1038  |HP            |57    |
# |1987|10   |297   |NW            |29    |
# |1987|10   |458   |NW            |50    |
# |1987|10   |961   |NW            |60    |
# |1987|10   |1028  |NW            |25    |
# |1987|10   |1202  |NW            |26    |
# |1987|10   |87    |PI            |60    |
# |1987|10   |164   |PI            |88    |
# |1987|10   |323   |PI            |42    |
# |1987|10   |1473  |PS            |22    |
# |1987|10   |1831  |PS            |59    |
# |1987|10   |1521  |null          |90    |
# |1987|10   |1891  |null          |22    |
# |1987|10   |1950  |null          |54    |
# |1987|10   |25    |UA            |28    |
# |1987|10   |239   |UA            |56    |
# |1987|10   |550   |UA            |86    |
# |1987|10   |632   |UA            |31    |
# |1987|10   |757   |UA            |1     |
# |1987|10   |846   |UA            |27    |
# |1987|10   |941   |UA            |31    |
# |1987|10   |955   |UA            |30    |
# |1987|10   |1051  |UA            |61    |
# |1987|10   |1159  |UA            |29    |
# |1987|10   |1193  |UA            |1     |
# |1987|10   |1401  |UA            |2     |
# |1987|10   |1559  |UA            |3     |
# |1987|10   |341   |WN            |31    |
# |1987|10   |167   |AA            |86    |
# |1987|10   |517   |AA            |59    |
# |1987|10   |641   |AA            |58    |
# |1987|10   |936   |AA            |61    |
# |1987|10   |974   |AA            |61    |
# |1987|10   |2060  |AA            |45    |
# |1987|10   |2510  |AA            |59    |
# |1987|10   |19    |US            |61    |
# |1987|10   |39    |US            |30    |
# |1987|10   |567   |US            |30    |
# |1987|10   |645   |US            |26    |
# |1987|10   |93    |CO            |60    |
# |1987|10   |646   |CO            |25    |
# |1987|10   |229   |null          |372   |
# |1987|10   |845   |null          |411   |
# |1987|10   |920   |null          |291   |
# |1987|10   |585   |null          |412   |
# |1987|10   |1012  |CO            |62    |
# |1987|10   |723   |DL            |62    |
# |1987|10   |962   |DL            |31    |
# |1987|10   |1043  |DL            |31    |
# |1987|10   |1566  |DL            |30    |
# |1987|10   |1934  |DL            |31    |
# |1987|10   |39    |EA            |55    |
# |1987|10   |434   |EA            |49    |
# |1987|10   |641   |EA            |60    |
# |1987|10   |734   |EA            |30    |
# |1987|10   |1115  |null          |114   |
# |1987|10   |1607  |null          |114   |
# |1987|10   |33    |HP            |58    |
# |1987|10   |398   |NW            |48    |
# |1987|10   |477   |NW            |29    |
# |1987|10   |478   |NW            |49    |
# |1987|10   |507   |NW            |55    |
# |1987|10   |856   |NW            |28    |
# |1987|10   |931   |NW            |60    |
# |1987|10   |1193  |NW            |29    |
# |1987|10   |257   |PA (1)        |31    |
# |1987|10   |537   |PA (1)        |31    |
# |1987|10   |290   |PI            |62    |
# |1987|10   |426   |PI            |30    |
# |1987|10   |700   |PI            |61    |
# |1987|10   |855   |PI            |143   |
# |1987|10   |914   |PI            |58    |
# |1987|10   |1560  |PS            |56    |
# |1987|10   |1714  |PS            |28    |
# |1987|10   |1724  |PS            |50    |
# |1987|10   |1928  |PS            |22    |
# |1987|10   |267   |TW            |30    |
# |1987|10   |276   |TW            |54    |
# |1987|10   |28    |UA            |59    |
# |1987|10   |300   |UA            |26    |
# |1987|10   |357   |UA            |59    |
# |1987|10   |455   |UA            |89    |
# |1987|10   |546   |UA            |30    |
# |1987|10   |697   |UA            |31    |
# |1987|10   |1122  |UA            |27    |
# |1987|10   |1892  |UA            |1     |
# |1987|10   |163   |WN            |61    |
# |1987|10   |952   |WN            |55    |
# |1987|10   |101   |AA            |59    |
# |1987|10   |304   |AA            |85    |
# |1987|10   |381   |AA            |91    |
# |1987|10   |850   |AA            |62    |
# |1987|10   |223   |US            |25    |
# |1987|10   |971   |US            |5     |
# |1987|10   |46    |AS            |30    |
# |1987|10   |64    |AS            |103   |
# |1987|10   |394   |AS            |60    |
# |1987|10   |750   |AS            |29    |
# |1987|10   |127   |CO            |25    |
# |1987|10   |157   |CO            |60    |
# |1987|10   |528   |null          |412   |
# |1987|10   |632   |null          |339   |
# |1987|10   |856   |null          |273   |
# |1987|10   |1075  |null          |181   |
# |1987|10   |831   |CO            |23    |
# |1987|10   |1177  |CO            |51    |
# |1987|10   |1791  |CO            |58    |
# |1987|10   |419   |DL            |85    |
# |1987|10   |556   |DL            |29    |
# |1987|10   |612   |DL            |29    |
# |1987|10   |745   |DL            |56    |
# |1987|10   |1446  |DL            |54    |
# |1987|10   |1789  |DL            |29    |
# |1987|10   |1853  |DL            |62    |
# |1987|10   |611   |EA            |27    |
# |1987|10   |818   |EA            |2     |
# |1987|10   |835   |EA            |2     |
# |1987|10   |986   |EA            |9     |
# |1987|10   |875   |null          |225   |
# |1987|10   |1849  |null          |93    |
# |1987|10   |1667  |EA            |30    |
# |1987|10   |30    |NW            |27    |
# |1987|10   |276   |NW            |57    |
# |1987|10   |310   |NW            |31    |
# |1987|10   |386   |NW            |59    |
# |1987|10   |606   |NW            |21    |
# |1987|10   |759   |NW            |31    |
# |1987|10   |1001  |NW            |29    |
# |1987|10   |580   |PA (1)        |27    |
# |1987|10   |881   |PI            |61    |
# |1987|10   |1864  |PS            |25    |
# |1987|10   |1948  |PS            |1     |
# |1987|10   |1402  |null          |22    |
# |1987|10   |1428  |null          |75    |
# |1987|10   |1478  |null          |34    |
# |1987|10   |575   |TW            |67    |
# |1987|10   |698   |TW            |37    |
# |1987|10   |760   |TW            |30    |
# |1987|10   |52    |UA            |30    |
# |1987|10   |95    |UA            |1     |
# |1987|10   |245   |UA            |31    |
# |1987|10   |454   |UA            |27    |
# |1987|10   |937   |UA            |34    |
# |1987|10   |1212  |UA            |59    |
# |1987|10   |1266  |UA            |1     |
# |1987|10   |1482  |UA            |59    |
# |1987|10   |234   |WN            |62    |
# |1987|10   |349   |WN            |57    |
# |1987|10   |433   |WN            |25    |
# |1987|10   |183   |AA            |25    |
# |1987|10   |218   |AA            |59    |
# |1987|10   |1013  |AA            |58    |
# |1987|10   |2009  |AA            |86    |
# |1987|10   |2211  |AA            |29    |
# |1987|10   |555   |US            |60    |
# |1987|10   |657   |US            |62    |
# |1987|10   |716   |US            |2     |
# |1987|10   |939   |US            |8     |
# |1987|10   |32    |null          |349   |
# |1987|10   |99    |null          |383   |
# |1987|10   |182   |null          |320   |
# |1987|10   |235   |null          |399   |
# |1987|10   |289   |null          |406   |
# |1987|10   |364   |null          |472   |
# |1987|10   |639   |null          |347   |
# |1987|10   |695   |null          |562   |
# |1987|10   |2230  |null          |29    |
# |1987|10   |2337  |null          |24    |
# |1987|10   |678   |DL            |60    |
# |1987|10   |693   |DL            |93    |
# |1987|10   |711   |DL            |27    |
# |1987|10   |1485  |DL            |60    |
# |1987|10   |1558  |DL            |31    |
# |1987|10   |1648  |DL            |56    |
# |1987|10   |1859  |DL            |62    |
# |1987|10   |1935  |DL            |30    |
# |1987|10   |378   |EA            |52    |
# |1987|10   |480   |EA            |25    |
# |1987|10   |518   |EA            |30    |
# |1987|10   |625   |EA            |31    |
# |1987|10   |892   |EA            |28    |
# |1987|10   |1138  |null          |83    |
# |1987|10   |1237  |null          |85    |
# |1987|10   |120   |NW            |55    |
# |1987|10   |653   |NW            |31    |
# |1987|10   |678   |NW            |56    |
# |1987|10   |453   |PI            |31    |
# |1987|10   |595   |PI            |62    |
# |1987|10   |735   |PI            |30    |
# |1987|10   |1707  |PS            |20    |
# |1987|10   |1961  |PS            |28    |
# |1987|10   |106   |TW            |22    |
# |1987|10   |1441  |null          |113   |
# |1987|10   |12    |UA            |27    |
# |1987|10   |412   |UA            |54    |
# |1987|10   |532   |UA            |117   |
# |1987|10   |581   |UA            |30    |
# |1987|10   |1259  |UA            |88    |
# |1987|10   |1262  |UA            |61    |
# |1987|10   |1273  |UA            |29    |
# |1987|10   |1828  |UA            |1     |
# |1987|10   |1018  |AA            |63    |
# |1987|10   |2097  |AA            |51    |
# |1987|10   |104   |US            |83    |
# |1987|10   |232   |US            |60    |
# |1987|10   |483   |US            |60    |
# |1987|10   |517   |US            |90    |
# |1987|10   |84    |AS            |122   |
# |1987|10   |451   |CO            |27    |
# |1987|10   |513   |CO            |28    |
# |1987|10   |733   |CO            |53    |
# |1987|10   |1     |null          |580   |
# |1987|10   |136   |null          |431   |
# |1987|10   |152   |null          |323   |
# |1987|10   |208   |null          |356   |
# |1987|10   |479   |null          |455   |
# |1987|10   |515   |null          |410   |
# |1987|10   |586   |null          |514   |
# |1987|10   |622   |null          |400   |
# |1987|10   |648   |null          |406   |
# |1987|10   |1018  |null          |148   |
# |1987|10   |2031  |null          |26    |
# |1987|10   |896   |null          |303   |
# |1987|10   |728   |null          |147   |
# |1987|10   |261   |DL            |57    |
# |1987|10   |470   |DL            |31    |
# |1987|10   |636   |DL            |93    |
# |1987|10   |805   |DL            |29    |
# |1987|10   |920   |DL            |83    |
# |1987|10   |1065  |DL            |155   |
# |1987|10   |1488  |DL            |60    |
# |1987|10   |1548  |DL            |29    |
# |1987|10   |1794  |DL            |31    |
# |1987|10   |646   |EA            |81    |
# |1987|10   |1141  |EA            |31    |
# |1987|10   |1135  |null          |116   |
# |1987|10   |1172  |null          |52    |
# |1987|10   |1443  |null          |145   |
# |1987|10   |250   |NW            |57    |
# |1987|10   |766   |NW            |46    |
# |1987|10   |816   |NW            |59    |
# |1987|10   |886   |NW            |57    |
# |1987|10   |987   |NW            |57    |
# |1987|10   |1191  |NW            |30    |
# |1987|10   |1279  |NW            |60    |
# |1987|10   |569   |PA (1)        |28    |
# |1987|10   |319   |PI            |51    |
# |1987|10   |431   |PI            |91    |
# |1987|10   |1401  |PS            |54    |
# |1987|10   |1412  |PS            |56    |
# |1987|10   |1510  |PS            |25    |
# |1987|10   |1530  |PS            |21    |
# |1987|10   |1552  |PS            |25    |
# |1987|10   |1578  |PS            |45    |
# |1987|10   |1589  |PS            |24    |
# |1987|10   |1629  |PS            |24    |
# |1987|10   |1731  |PS            |30    |
# |1987|10   |1756  |PS            |24    |
# |1987|10   |629   |TW            |60    |
# |1987|10   |129   |UA            |60    |
# |1987|10   |325   |UA            |29    |
# |1987|10   |498   |UA            |30    |
# |1987|10   |869   |UA            |30    |
# |1987|10   |1180  |UA            |31    |
# |1987|10   |1510  |UA            |29    |
# |1987|10   |151   |AA            |62    |
# |1987|10   |493   |AA            |59    |
# |1987|10   |567   |AA            |91    |
# |1987|10   |668   |AA            |60    |
# |1987|10   |135   |US            |58    |
# |1987|10   |247   |US            |27    |
# |1987|10   |986   |US            |5     |
# |1987|10   |747   |AS            |27    |
# |1987|10   |72    |CO            |53    |
# |1987|10   |592   |CO            |24    |
# |1987|10   |492   |null          |469   |
# |1987|10   |552   |null          |565   |
# |1987|10   |812   |null          |453   |
# |1987|10   |700   |null          |315   |
# |1987|10   |731   |null          |403   |
# |1987|10   |734   |null          |404   |
# |1987|10   |773   |CO            |58    |
# |1987|10   |975   |CO            |31    |
# |1987|10   |212   |DL            |62    |
# |1987|10   |320   |DL            |30    |
# |1987|10   |702   |DL            |61    |
# |1987|10   |942   |DL            |31    |
# |1987|10   |1949  |DL            |29    |
# |1987|10   |446   |EA            |116   |
# |1987|10   |890   |EA            |29    |
# |1987|10   |938   |EA            |52    |
# |1987|10   |978   |EA            |3     |
# |1987|10   |777   |null          |205   |
# |1987|10   |768   |null          |218   |
# |1987|10   |989   |null          |166   |
# |1987|10   |601   |NW            |56    |
# |1987|10   |454   |PA (1)        |3     |
# |1987|10   |558   |PA (1)        |60    |
# |1987|10   |173   |PI            |16    |
# |1987|10   |370   |PI            |62    |
# |1987|10   |424   |PI            |59    |
# |1987|10   |437   |PI            |44    |
# |1987|10   |848   |PI            |92    |
# |1987|10   |1529  |PS            |25    |
# |1987|10   |1746  |null          |31    |
# |1987|10   |1823  |null          |22    |
# |1987|10   |150   |TW            |42    |
# |1987|10   |469   |TW            |9     |
# |1987|10   |659   |TW            |56    |
# |1987|10   |27    |UA            |27    |
# |1987|10   |1139  |UA            |1     |
# |1987|10   |1566  |UA            |30    |
# |1987|10   |780   |WN            |61    |
# |1987|10   |791   |WN            |47    |
# |1987|10   |1277  |null          |2     |
# |1987|10   |90    |AA            |30    |
# |1987|10   |114   |AA            |61    |
# |1987|10   |464   |AA            |62    |
# |1987|10   |2024  |AA            |51    |
# |1987|10   |2512  |AA            |60    |
# |1987|10   |116   |US            |30    |
# |1987|10   |136   |US            |57    |
# |1987|10   |211   |US            |31    |
# |1987|10   |200   |AS            |90    |
# |1987|10   |710   |AS            |24    |
# |1987|10   |99    |CO            |25    |
# |1987|10   |184   |CO            |58    |
# |1987|10   |441   |CO            |30    |
# |1987|10   |661   |CO            |30    |
# |1987|10   |62    |null          |595   |
# |1987|10   |97    |null          |354   |
# |1987|10   |314   |null          |441   |
# |1987|10   |387   |null          |391   |
# |1987|10   |507   |null          |426   |
# |1987|10   |881   |null          |609   |
# |1987|10   |724   |null          |275   |
# |1987|10   |1796  |CO            |60    |
# |1987|10   |337   |DL            |59    |
# |1987|10   |559   |DL            |61    |
# |1987|10   |892   |DL            |30    |
# |1987|10   |922   |DL            |30    |
# |1987|10   |976   |EA            |26    |
# |1987|10   |1272  |null          |56    |
# |1987|10   |1296  |null          |90    |
# |1987|10   |1481  |null          |153   |
# |1987|10   |1685  |null          |145   |
# |1987|10   |1669  |EA            |25    |
# |1987|10   |1843  |EA            |4     |
# |1987|10   |481   |HP            |27    |
# |1987|10   |360   |NW            |61    |
# |1987|10   |520   |NW            |20    |
# |1987|10   |776   |NW            |31    |
# |1987|10   |1278  |NW            |142   |
# |1987|10   |269   |PA (1)        |31    |
# |1987|10   |440   |PA (1)        |25    |
# |1987|10   |125   |PI            |30    |
# |1987|10   |746   |PI            |62    |
# |1987|10   |788   |PI            |31    |
# |1987|10   |1406  |PS            |19    |
# |1987|10   |1447  |PS            |23    |
# |1987|10   |1749  |PS            |47    |
# |1987|10   |1828  |PS            |50    |
# |1987|10   |1943  |PS            |30    |
# |1987|10   |1968  |null          |28    |
# |1987|10   |402   |TW            |27    |
# |1987|10   |562   |TW            |59    |
# |1987|10   |128   |UA            |61    |
# |1987|10   |1772  |UA            |1     |
# |1987|10   |1812  |UA            |4     |
# |1987|10   |223   |WN            |22    |
# |1987|10   |272   |WN            |26    |
# |1987|10   |403   |WN            |54    |
# |1987|10   |435   |WN            |44    |
# |1987|10   |797   |WN            |67    |
# |1987|10   |66    |AA            |60    |
# |1987|10   |120   |AA            |59    |
# |1987|10   |130   |AA            |62    |
# |1987|10   |182   |AA            |29    |
# |1987|10   |288   |AA            |58    |
# |1987|10   |413   |AA            |60    |
# |1987|10   |2136  |AA            |26    |
# |1987|10   |134   |US            |55    |
# |1987|10   |155   |US            |24    |
# |1987|10   |197   |US            |62    |
# |1987|10   |293   |US            |60    |
# |1987|10   |510   |US            |57    |
# |1987|10   |526   |US            |62    |
# |1987|10   |139   |CO            |58    |
# |1987|10   |75    |null          |363   |
# |1987|10   |143   |null          |238   |
# |1987|10   |360   |null          |423   |
# |1987|10   |365   |null          |379   |
# |1987|10   |511   |null          |495   |
# |1987|10   |886   |null          |407   |
# |1987|10   |1013  |null          |86    |
# |1987|10   |797   |null          |234   |
# |1987|10   |1235  |CO            |110   |
# |1987|10   |170   |DL            |28    |
# |1987|10   |439   |DL            |58    |
# |1987|10   |760   |DL            |61    |
# |1987|10   |1096  |DL            |61    |
# |1987|10   |1584  |DL            |21    |
# |1987|10   |1904  |DL            |31    |
# |1987|10   |48    |EA            |28    |
# |1987|10   |105   |EA            |56    |
# |1987|10   |1207  |null          |175   |
# |1987|10   |1709  |null          |87    |
# |1987|10   |1651  |null          |174   |
# |1987|10   |1401  |EA            |22    |
# |1987|10   |1621  |EA            |29    |
# |1987|10   |1634  |EA            |31    |
# |1987|10   |250   |HP            |83    |
# |1987|10   |877   |HP            |62    |
# |1987|10   |328   |NW            |29    |
# |1987|10   |84    |PI            |93    |
# |1987|10   |94    |PI            |117   |
# |1987|10   |308   |PI            |62    |
# |1987|10   |547   |PI            |61    |
# |1987|10   |862   |PI            |31    |
# |1987|10   |888   |PI            |62    |
# |1987|10   |951   |PI            |26    |
# |1987|10   |1770  |PS            |51    |
# |1987|10   |1831  |null          |59    |
# |1987|10   |523   |TW            |57    |
# |1987|10   |573   |TW            |59    |
# |1987|10   |584   |TW            |24    |
# |1987|10   |731   |TW            |59    |
# |1987|10   |303   |UA            |30    |
# |1987|10   |1165  |UA            |7     |
# |1987|10   |707   |WN            |5     |
# |1987|10   |930   |WN            |60    |
# |1987|10   |176   |AA            |122   |
# |1987|10   |688   |AA            |29    |
# |1987|10   |862   |AA            |59    |
# |1987|10   |933   |AA            |60    |
# |1987|10   |937   |AA            |58    |
# |1987|10   |2392  |AA            |25    |
# |1987|10   |177   |US            |30    |
# |1987|10   |129   |CO            |25    |
# |1987|10   |190   |CO            |56    |
# |1987|10   |463   |CO            |55    |
# |1987|10   |467   |CO            |52    |
# |1987|10   |474   |CO            |20    |
# |1987|10   |667   |CO            |56    |
# |1987|10   |368   |null          |290   |
# |1987|10   |394   |null          |444   |
# |1987|10   |569   |null          |439   |
# |1987|10   |1089  |null          |88    |
# |1987|10   |2055  |null          |30    |
# |1987|10   |2371  |null          |30    |
# |1987|10   |2607  |null          |26    |
# |1987|10   |536   |null          |399   |
# |1987|10   |722   |null          |318   |
# |1987|10   |1024  |CO            |58    |
# |1987|10   |1080  |CO            |30    |
# |1987|10   |1095  |CO            |29    |
# |1987|10   |294   |DL            |31    |
# |1987|10   |316   |DL            |31    |
# |1987|10   |343   |DL            |62    |
# |1987|10   |574   |DL            |60    |
# |1987|10   |662   |DL            |89    |
# |1987|10   |734   |DL            |60    |
# |1987|10   |954   |DL            |31    |
# |1987|10   |498   |EA            |25    |
# |1987|10   |1182  |null          |107   |
# |1987|10   |1600  |null          |59    |
# |1987|10   |1602  |null          |78    |
# |1987|10   |1714  |null          |87    |
# |1987|10   |1653  |EA            |56    |
# |1987|10   |11    |HP            |49    |
# |1987|10   |857   |HP            |61    |
# |1987|10   |47    |NW            |27    |
# |1987|10   |302   |NW            |27    |
# |1987|10   |549   |NW            |59    |
# |1987|10   |1401  |NW            |26    |
# |1987|10   |79    |PI            |111   |
# |1987|10   |704   |PI            |123   |
# |1987|10   |790   |PI            |26    |
# |1987|10   |1492  |PS            |49    |
# |1987|10   |1840  |PS            |49    |
# |1987|10   |1591  |null          |81    |
# |1987|10   |223   |TW            |58    |
# |1987|10   |260   |TW            |36    |
# |1987|10   |298   |TW            |31    |
# |1987|10   |203   |UA            |29    |
# |1987|10   |349   |UA            |29    |
# |1987|10   |1029  |UA            |4     |
# |1987|10   |1185  |UA            |29    |
# |1987|10   |1281  |UA            |28    |
# |1987|10   |1620  |UA            |30    |
# |1987|10   |39    |WN            |60    |
# |1987|10   |75    |AA            |55    |
# |1987|10   |404   |AA            |57    |
# |1987|10   |638   |AA            |61    |
# |1987|10   |2403  |AA            |31    |
# |1987|10   |62    |US            |61    |
# |1987|10   |670   |CO            |52    |
# |1987|10   |175   |null          |336   |
# |1987|10   |295   |null          |378   |
# |1987|10   |2071  |null          |58    |
# |1987|10   |799   |CO            |58    |
# |1987|10   |1179  |CO            |31    |
# |1987|10   |1228  |CO            |21    |
# |1987|10   |1753  |CO            |25    |
# |1987|10   |1776  |CO            |89    |
# |1987|10   |1793  |CO            |31    |
# |1987|10   |431   |DL            |62    |
# |1987|10   |616   |DL            |56    |
# |1987|10   |620   |DL            |62    |
# |1987|10   |1005  |DL            |31    |
# |1987|10   |1058  |DL            |27    |
# |1987|10   |1063  |DL            |60    |
# |1987|10   |1653  |DL            |93    |
# |1987|10   |237   |EA            |59    |
# |1987|10   |341   |EA            |58    |
# |1987|10   |347   |EA            |48    |
# |1987|10   |497   |EA            |55    |
# |1987|10   |695   |EA            |58    |
# |1987|10   |840   |EA            |27    |
# |1987|10   |1151  |EA            |31    |
# |1987|10   |1161  |EA            |22    |
# |1987|10   |1241  |null          |82    |
# |1987|10   |810   |NW            |27    |
# |1987|10   |820   |NW            |58    |
# |1987|10   |1474  |NW            |31    |
# |1987|10   |244   |PA (1)        |27    |
# |1987|10   |358   |PI            |92    |
# |1987|10   |464   |PI            |62    |
# |1987|10   |701   |PI            |26    |
# |1987|10   |909   |PI            |54    |
# |1987|10   |1765  |PS            |33    |
# |1987|10   |1801  |PS            |25    |
# |1987|10   |28    |TW            |60    |
# |1987|10   |4649  |null          |1     |
# |1987|10   |781   |TW            |30    |
# |1987|10   |87    |UA            |57    |
# |1987|10   |111   |UA            |56    |
# |1987|10   |155   |UA            |55    |
# |1987|10   |438   |UA            |61    |
# |1987|10   |746   |UA            |1     |
# |1987|10   |875   |UA            |2     |
# |1987|10   |931   |UA            |29    |
# |1987|10   |1115  |UA            |29    |
# |1987|10   |1207  |UA            |30    |
# |1987|10   |1480  |UA            |31    |
# |1987|10   |306   |WN            |79    |
# |1987|10   |430   |WN            |31    |
# |1987|10   |670   |WN            |73    |
# |1987|10   |15    |AA            |23    |
# |1987|10   |479   |AA            |57    |
# |1987|10   |294   |US            |30    |
# |1987|10   |687   |US            |78    |
# |1987|10   |902   |US            |15    |
# |1987|10   |945   |US            |19    |
# |1987|10   |191   |CO            |59    |
# |1987|10   |352   |CO            |26    |
# |1987|10   |89    |null          |458   |
# |1987|10   |263   |null          |530   |
# |1987|10   |454   |null          |301   |
# |1987|10   |373   |null          |235   |
# |1987|10   |584   |null          |402   |
# |1987|10   |1137  |CO            |53    |
# |1987|10   |1160  |CO            |58    |
# |1987|10   |17    |DL            |52    |
# +----+-----+------+--------------+------+
# only showing top 1000 rows

# %% [markdown]
# # References
#
# ##### https://s3.amazonaws.com/assets.datacamp.com/blog_assets/PySpark_SQL_Cheat_Sheet_Python.pdf
# ##### https://s3.amazonaws.com/assets.datacamp.com/blog_assets/PySpark_SQL_Cheat_Sheet_Python.pdf
# ##### https://changhsinlee.com/pyspark-dataframe-basics/
# ##### https://www.analyticsvidhya.com/blog/2016/10/spark-dataframe-and-operations/

# %%
df.show()

# %%
spark = SparkSession.builder.getOrCreate()
df.createOrReplaceTempView("flights")

sqlDF = spark.sql("SELECT * FROM flights limit 5")
sqlDF.show()
# Out:
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# |YEAR|MONTH|DAY_OF_MONTH|DAY_OF_WEEK|            FL_DATE|UNIQUE_CARRIER|TAIL_NUM|FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN|ORIGIN_STATE_ABR|DEST_AIRPORT_ID|DEST|DEST_STATE_ABR|CRS_DEP_TIME|DEP_TIME|DEP_DELAY|DEP_DELAY_NEW|DEP_DEL15|DEP_DELAY_GROUP|TAXI_OUT|WHEELS_OFF|WHEELS_ON|TAXI_IN|CRS_ARR_TIME|ARR_TIME|ARR_DELAY|ARR_DELAY_NEW|ARR_DEL15|ARR_DELAY_GROUP|CANCELLED|CANCELLATION_CODE|DIVERTED|CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|AIR_TIME|FLIGHTS|DISTANCE|DISTANCE_GROUP|CARRIER_DELAY|WEATHER_DELAY|NAS_DELAY|SECURITY_DELAY|LATE_AIRCRAFT_DELAY|_c44|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# |1987|   10|           1|          4|1987-10-01 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1117|    -35.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           2|          5|1987-10-02 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     901|      1.0|          1.0|      0.0|              0|    null|      null|     null|   null|        1152|    1137|    -15.0|          0.0|      0.0|             -1|      0.0|             null|     0.0|           352.0|              336.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           3|          6|1987-10-03 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     859|     -1.0|          0.0|      0.0|             -1|    null|      null|     null|   null|        1152|    1111|    -41.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              312.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           4|          7|1987-10-04 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     900|      0.0|          0.0|      0.0|              0|    null|      null|     null|   null|        1152|    1116|    -36.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              316.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# |1987|   10|           5|          1|1987-10-05 00:00:00|            AA|    null|     1|            12478|   JFK|              NY|          12892| LAX|            CA|         900|     902|      2.0|          2.0|      0.0|              0|    null|      null|     null|   null|        1152|    1119|    -33.0|          0.0|      0.0|             -2|      0.0|             null|     0.0|           352.0|              317.0|    null|    1.0|  2475.0|            10|         null|         null|     null|          null|               null|null|
# +----+-----+------------+-----------+-------------------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+

# %%
sqlDF2 = spark.sql("SELECT UNIQUE_CARRIER, count(UNIQUE_CARRIER) FROM flights GROUP BY UNIQUE_CARRIER ")
sqlDF2.show()
# Out:
# +--------------+---------------------+
# |UNIQUE_CARRIER|count(UNIQUE_CARRIER)|
# +--------------+---------------------+
# |            EA|                37048|
# |            UA|                52952|
# |            PI|                39228|
# |            PS|                14405|
# |            AA|                56091|
# |            NW|                37590|
# |            HP|                15026|
# |            TW|                23823|
# |            DL|                63104|
# |            US|                32293|
# |            AS|                 7432|
# |            CO|                42756|
# |        PA (1)|                 5134|
# |            WN|                21738|
# +--------------+---------------------+
